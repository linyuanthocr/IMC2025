# %% [markdown]
# ### IMC-2025 Rank-5 Solution Notebook
# #### Author: Sayan Paul
# #### [Link to Kaggle Discussion](https://www.kaggle.com/competitions/image-matching-challenge-2025/discussion/583711)

# %%
# %cd /kaggle/working/
# !rm -r /kaggle/working/mast3r/
# !rm -r /kaggle/working/miniconda/
# !rm -r /kaggle/working/result/
# !rm /kaggle/working/submission.csv

# !tar -xzf /kaggle/usr/lib/imc25_mast3r_sfm_install_utility_script_4/mast3r.tar.gz -C /kaggle/working/
# !tar -xzf /kaggle/usr/lib/imc25_mast3r_sfm_install_utility_script_4/miniconda.tar.gz -C /kaggle/working/
# !ls -lh .
# Out:
# /kaggle/working
# rm: cannot remove '/kaggle/working/mast3r/': No such file or directory
# rm: cannot remove '/kaggle/working/miniconda/': No such file or directory
# rm: cannot remove '/kaggle/working/result/': No such file or directory
# rm: cannot remove '/kaggle/working/submission.csv': No such file or directory
# total 64K
# drwxr-xr-x 10 root root 4.0K Jun 15 10:30 mast3r
# drwxr-xr-x 19 root root 4.0K Jun 15 10:18 miniconda
# ----------  1 root root  55K Jun 17 18:17 __notebook__.ipynb

# %%
PREFIX_KAGGLE_ROOT = ""
SUBMISSION_FILE = f"{PREFIX_KAGGLE_ROOT}/kaggle/working/submission.csv"

# %%
# %cd {PREFIX_KAGGLE_ROOT}/kaggle/working/mast3r
# Out:
# /kaggle/working/mast3r

# %%
# %%writefile mast3r/demo_colmapdb.py

import os
import copy
import torch

from kapture.converter.colmap.database_extra import kapture_to_colmap
from kapture.converter.colmap.database import COLMAPDatabase

from mast3r.colmap.mapping import kapture_import_image_folder_or_list, run_mast3r_matching
from mast3r.retrieval.processor import Retriever
from mast3r.image_pairs import make_pairs

import mast3r.utils.path_to_dust3r  # noqa
from dust3r.utils.image import load_images


def make_pairs_from_pair_idxs_list(imgs, pair_idxs_list, symmetrize=True):
    pairs = []
    for (i,j) in pair_idxs_list:
        pairs.append((imgs[i], imgs[j]))

    if symmetrize:
        pairs += [(img2, img1) for img1, img2 in pairs]

    return pairs


def get_colmapdb_from_mast3r_matches(outdir, filelist, image_size, model, retrieval_model, 
                                     scenegraph_type, winsize, refid, win_cyclic, shared_intrinsics,
                                     silent, device, delete_cache, image_square_ok, pair_idxs_list=None):

    imgs = load_images(filelist, size=image_size, verbose=not silent, square_ok=image_square_ok)
    if len(imgs) == 1:
        imgs = [imgs[0], copy.deepcopy(imgs[0])]
        imgs[1]['idx'] = 1
        filelist = [filelist[0], filelist[0]]

    scene_graph_params = [scenegraph_type]
    if scenegraph_type in ["swin", "logwin"]:
        scene_graph_params.append(str(winsize))
    elif scenegraph_type == "oneref":
        scene_graph_params.append(str(refid))
    elif scenegraph_type == "retrieval":
        scene_graph_params.append(str(winsize))  # Na
        scene_graph_params.append(str(refid))  # k

    if scenegraph_type in ["swin", "logwin"] and not win_cyclic:
        scene_graph_params.append('noncyclic')
    scene_graph = '-'.join(scene_graph_params)

    sim_matrix = None
    if 'retrieval' in scenegraph_type:
        assert retrieval_model is not None
        retriever = Retriever(retrieval_model, backbone=model, device=device)
        with torch.no_grad():
            sim_matrix = retriever(filelist)

        # Cleanup
        del retriever
        torch.cuda.empty_cache()

    if scene_graph == "pair_idxs_list":
        assert pair_idxs_list is not None
        pairs = make_pairs_from_pair_idxs_list(imgs, pair_idxs_list, symmetrize=True)
    else:
        pairs = make_pairs(imgs, scene_graph=scene_graph, prefilter=None, symmetrize=True, sim_mat=sim_matrix)


    root_path = os.path.commonpath(filelist)
    filelist_relpath = [
        os.path.relpath(filename, root_path).replace('\\', '/')
        for filename in filelist
    ]
    kdata = kapture_import_image_folder_or_list((root_path, filelist_relpath), shared_intrinsics)
    image_pairs = [
        (filelist_relpath[img1['idx']], filelist_relpath[img2['idx']])
        for img1, img2 in pairs
    ]

    colmap_db_path = os.path.join(outdir, 'colmap.db')
    if os.path.isfile(colmap_db_path):
        os.remove(colmap_db_path)

    os.makedirs(os.path.dirname(colmap_db_path), exist_ok=True)
    colmap_db = COLMAPDatabase.connect(colmap_db_path)
    try:
        kapture_to_colmap(kdata, root_path, tar_handler=None, database=colmap_db,
                          keypoints_type=None, descriptors_type=None, export_two_view_geometry=False)
        colmap_image_pairs = run_mast3r_matching(model, image_size, 16, device,
                                                 kdata, root_path, image_pairs, colmap_db,
                                                 False, 5, 1.001,
                                                 False, 3)
        colmap_db.close()
    except Exception as e:
        print(f'Error {e}')
        colmap_db.close()
        exit(1)

    if len(colmap_image_pairs) == 0:
        raise Exception("no matches were kept")

    
    colmap_world_to_cam = {}
    
    pairs_path = os.path.join(outdir, "pairs.txt")
    
    f = open(pairs_path, "w")
    for image_path1, image_path2 in colmap_image_pairs:
        f.write("{} {}\n".format(image_path1, image_path2))
    f.close()
    
    return colmap_db_path, pairs_path
# Out:
# Writing mast3r/demo_colmapdb.py

# %%
# %%writefile retrieval_processor.py

import os
import argparse
import numpy as np
import torch

import cv2
from glob import glob
from typing import Optional, List, Tuple

from mast3r.model import AsymmetricMASt3R
from mast3r.retrieval.model import RetrievalModel, extract_local_features

try:
    import faiss
    faiss.StandardGpuResources()  # when loading the checkpoint, it will try to instanciate FaissGpuL2Index
except AttributeError as e:
    import asmk.index

    class FaissCpuL2Index(asmk.index.FaissL2Index):
        def __init__(self, gpu_id):
            super().__init__()
            self.gpu_id = gpu_id

        def _faiss_index_flat(self, dim):
            """Return initialized faiss.IndexFlatL2"""
            return faiss.IndexFlatL2(dim)

    asmk.index.FaissGpuL2Index = FaissCpuL2Index

from asmk import asmk_method  # noqa


def get_args_parser():
    parser = argparse.ArgumentParser('Retrieval scores from a set of retrieval', add_help=True, allow_abbrev=False)
    parser.add_argument('--retrieval_model', type=str, default="./checkpoints/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_trainingfree.pth",
                        help="shortname of a retrieval model or path to the corresponding .pth")
    parser.add_argument('--backbone_model', type=str, default="./checkpoints/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth")

    parser.add_argument('--input_dir', type=str, required=True,
                        help="directory containing images")
    parser.add_argument('--out_dir', type=str, required=True, help="numpy file where to store the matrix score")
    return parser


def get_impaths(imlistfile):
    with open(imlistfile, 'r') as fid:
        impaths = [f for f in imlistfile.read().splitlines() if not f.startswith('#')
                   and len(f) > 0]  # ignore comments and empty lines
    return impaths


def get_impaths_from_imdir(imdir, extensions=['png', 'jpg', 'PNG', 'JPG']):
    assert os.path.isdir(imdir)
    impaths = [os.path.join(imdir, f) for f in sorted(os.listdir(imdir)) if any(f.endswith(ext) for ext in extensions)]
    return impaths


def get_impaths_from_imdir_or_imlistfile(input_imdir_or_imlistfile):
    if os.path.isfile(input_imdir_or_imlistfile):
        return get_impaths(input_imdir_or_imlistfile)
    else:
        return get_impaths_from_imdir(input_imdir_or_imlistfile)


class Retriever(object):
    def __init__(self, modelname, backbone=None, device='cuda'):
        # load the model
        assert os.path.isfile(modelname), modelname
        print(f'Loading retrieval model from {modelname}')
        ckpt = torch.load(modelname, 'cpu')  # TODO from pretrained to download it automatically
        ckpt_args = ckpt['args']
        if backbone is None:
            backbone = AsymmetricMASt3R.from_pretrained(ckpt_args.pretrained)
        self.model = RetrievalModel(
            backbone, freeze_backbone=ckpt_args.freeze_backbone, prewhiten=ckpt_args.prewhiten,
            hdims=list(map(int, ckpt_args.hdims.split('_'))) if len(ckpt_args.hdims) > 0 else "",
            residual=getattr(ckpt_args, 'residual', False), postwhiten=ckpt_args.postwhiten,
            featweights=ckpt_args.featweights, nfeat=ckpt_args.nfeat
        ).to(device)
        self.device = device
        msg = self.model.load_state_dict(ckpt['model'], strict=False)
        assert all(k.startswith('backbone') for k in msg.missing_keys)
        assert len(msg.unexpected_keys) == 0
        self.imsize = ckpt_args.imsize

        # load the asmk codebook
        dname, bname = os.path.split(modelname)  # TODO they should both be in the same file ?
        bname_splits = bname.split('_')
        cache_codebook_fname = os.path.join(dname, '_'.join(bname_splits[:-1]) + '_codebook.pkl')
        assert os.path.isfile(cache_codebook_fname), cache_codebook_fname
        asmk_params = {'index': {'gpu_id': 0}, 'train_codebook': {'codebook': {'size': '64k'}},
                       'build_ivf': {'kernel': {'binary': True}, 'ivf': {'use_idf': False},
                                     'quantize': {'multiple_assignment': 1}, 'aggregate': {}},
                       'query_ivf': {'quantize': {'multiple_assignment': 5}, 'aggregate': {},
                                     'search': {'topk': None},
                                     'similarity': {'similarity_threshold': 0.0, 'alpha': 3.0}}}
        asmk_params['train_codebook']['codebook']['size'] = ckpt_args.nclusters
        self.asmk = asmk_method.ASMKMethod.initialize_untrained(asmk_params)
        self.asmk = self.asmk.train_codebook(None, cache_path=cache_codebook_fname)

    def __call__(self, input_imdir_or_imlistfile, outfile=None):
        # get impaths
        if isinstance(input_imdir_or_imlistfile, str):
            impaths = get_impaths_from_imdir_or_imlistfile(input_imdir_or_imlistfile)
        else:
            impaths = input_imdir_or_imlistfile  # we're assuming a list has been passed
        print(f'Found {len(impaths)} images')

        # build the database
        feat, ids = extract_local_features(self.model, impaths, self.imsize, tocpu=True, device=self.device)
        feat = feat.cpu().numpy()
        ids = ids.cpu().numpy()
        asmk_dataset = self.asmk.build_ivf(feat, ids)

        # we actually retrieve the same set of images
        metadata, query_ids, ranks, ranked_scores = asmk_dataset.query_ivf(feat, ids)

        # well ... scores are actually reordered according to ranks ...
        # so we redo it the other way around...
        scores = np.empty_like(ranked_scores)
        scores[np.arange(ranked_scores.shape[0])[:, None], ranks] = ranked_scores

        # save
        if outfile is not None:
            if not os.path.isdir(os.path.dirname(outfile)):
                os.makedirs(os.path.dirname(outfile), exist_ok=True)
            np.save(outfile, scores)
            print(f'Scores matrix saved in {outfile}')
        return scores


#--------------------------------------------------------------------------------------------------------------------------

def get_similarity_pairs(
    sim_matrix: np.ndarray,
    top_k: Optional[int] = None,
    topk_percentile: Optional[float] = None,
    sim_score_thres: Optional[float] = None,
    include_symmetric: bool = False,
    top_k_max : Optional[int] = 50,
) -> List[Tuple[int, int]]:
    
    n = sim_matrix.shape[0]
    pairs = set()

    for i in range(n):
        sim_list = []
        for j in range(n):
            if i == j:
                continue

            score = sim_matrix[i, j]
            if sim_score_thres is not None and score < sim_score_thres:
                continue

            sim_list.append((j, score))

        sim_list.sort(key=lambda x: -x[1])

        if topk_percentile is not None:
            k = max(1, int(topk_percentile * len(sim_list)))
            # k is a subset of sim_list based on ratio, so can't be greater than it's len, but we can restrict it to top_k_max
            if top_k is None:
                sim_list = sim_list[:min(k, top_k_max)]
            else:
                sim_list = sim_list[:min(max(min(k, top_k_max), top_k), len(sim_list)-1)]
        elif top_k is not None:
            # here top_k can be greater than len of sim_list, so must be restricted
            sim_list = sim_list[:min(top_k, len(sim_list)-1)]

        for j, _ in sim_list:
            if include_symmetric:
                pairs.add((i, j))
            else:
                # Only add (i, j) if sim[i, j] >= sim[j, i] to avoid duplicate symmetric matches
                if sim_matrix[i, j] >= sim_matrix[j, i]:
                    pairs.add((i, j))

    return sorted(pairs)


def get_retriever_model(retrieval_model_weights=None,
                       backbone_model_weights=None,
                       device="cpu"):
    
    if retrieval_model_weights is None:
        retrieval_model_weights=f"{os.path.dirname(__file__)}/checkpoints/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_trainingfree.pth"
        backbone_model_weights=f"{os.path.dirname(__file__)}/checkpoints/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth"

    backbone_model = AsymmetricMASt3R.from_pretrained(backbone_model_weights).to(device)
    retriever = Retriever(retrieval_model_weights, backbone=backbone_model, device=device)
    return retriever
# Out:
# Writing retrieval_processor.py

# %%
# %%writefile mast3r_colmapdb_module.py

import os

from mast3r.model import AsymmetricMASt3R
from mast3r.demo_colmapdb import get_colmapdb_from_mast3r_matches

def get_colmapdb_from_mast3r_matching(outputdir, filelist, scenegraph_type="complete", pair_idxs_list=None,
                                      shared_intrinsics = False, image_square_ok=False, device="cpu"):

    image_size = 512
    backbone_model_weights=f"{os.path.dirname(__file__)}/checkpoints/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth"
    retrieval_model_weights=f"{os.path.dirname(__file__)}/checkpoints/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_trainingfree.pth"
    
    if pair_idxs_list is not None:
        scenegraph_type = "pair_idxs_list"

    if scenegraph_type in ["complete", "pair_idxs_list"]:
        winsize, refid, win_cyclic = None, None, False
    else:
        raise "Other scene_graph types yet to be implemented !!!"

    model = AsymmetricMASt3R.from_pretrained(backbone_model_weights).to(device)
    silent = False

    colmap_db_path, colmap_pairs_path = get_colmapdb_from_mast3r_matches(outputdir, filelist, image_size, model, retrieval_model_weights, 
                                                                        scenegraph_type, winsize, refid, win_cyclic, shared_intrinsics,
                                                                        silent, device, delete_cache=False, image_square_ok=image_square_ok,
                                                                        pair_idxs_list=pair_idxs_list)
    
    print("Exported COLMAP DB and pairs.txt at :-")
    print(colmap_db_path)
    print(colmap_pairs_path)
    print("--"*50)

    return colmap_db_path, colmap_pairs_path
# Out:
# Writing mast3r_colmapdb_module.py

# %%
# %%writefile imc25_prediction_utils.py

import json
import dataclasses
import numpy as np
import pandas as pd

@dataclasses.dataclass
class Prediction:
    image_id: str | None  # A unique identifier for the row -- unused otherwise. Used only on the hidden test set.
    dataset: str
    filename: str
    cluster_index: int | None = None
    rotation: np.ndarray | None = None
    translation: np.ndarray | None = None

def save_predictions(predictions, filepath):
    def convert(obj):
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        if dataclasses.is_dataclass(obj):
            return dataclasses.asdict(obj)
        raise TypeError(f"Type {type(obj)} not serializable")
    
    with open(filepath, "w") as f:
        json.dump(predictions, f, default=convert, indent=2)


def load_predictions(filepath):
    with open(filepath, "r") as f:
        data = json.load(f)
    
    return [
        Prediction(
            image_id=item["image_id"],
            dataset=item["dataset"],
            filename=item["filename"],
            cluster_index=item.get("cluster_index"),
            rotation=np.array(item["rotation"]) if item.get("rotation") is not None else None,
            translation=np.array(item["translation"]) if item.get("translation") is not None else None
        )
        for item in data
    ]



def write_to_submission_file(submission_file, dataset_preds, is_train):
    array_to_str = lambda array: ';'.join([f"{x:.09f}" for x in array])
    none_to_str = lambda n: ';'.join(['nan'] * n)
    
    with open(submission_file, 'w') as f:
        if is_train:
            f.write('dataset,scene,image,rotation_matrix,translation_vector\n')
            for dataset in dataset_preds:
                for prediction in dataset_preds[dataset]:
                    cluster_name = 'outliers' if prediction.cluster_index is None else f'cluster{prediction.cluster_index}'
                    rotation = none_to_str(9) if prediction.rotation is None else array_to_str(prediction.rotation.flatten())
                    translation = none_to_str(3) if prediction.translation is None else array_to_str(prediction.translation)
                    f.write(f'{prediction.dataset},{cluster_name},{prediction.filename},{rotation},{translation}\n')
        else:
            f.write('image_id,dataset,scene,image,rotation_matrix,translation_vector\n')
            for dataset in dataset_preds:
                for prediction in dataset_preds[dataset]:
                    cluster_name = 'outliers' if prediction.cluster_index is None else f'cluster{prediction.cluster_index}'
                    rotation = none_to_str(9) if prediction.rotation is None else array_to_str(prediction.rotation.flatten())
                    translation = none_to_str(3) if prediction.translation is None else array_to_str(prediction.translation)
                    f.write(f'{prediction.image_id},{prediction.dataset},{cluster_name},{prediction.filename},{rotation},{translation}\n')
    
    print("Submission File written to : ", submission_file)



def read_sample_submission_file(sample_submission_csv, is_train=False):
    samples = {}
    competition_data = pd.read_csv(sample_submission_csv)
    for _, row in competition_data.iterrows():
        # Note: For the test data, the "scene" column has no meaning, and the rotation_matrix and translation_vector columns are random.
        if row.dataset not in samples:
            samples[row.dataset] = []
        samples[row.dataset].append(
            Prediction(
                image_id=None if is_train else row.image_id,
                dataset=row.dataset,
                filename=row.image
            )
        )
    
    return samples
# Out:
# Writing imc25_prediction_utils.py

# %%
# %%writefile imc25_mast3r_shortlist_matching_pycolmap_subp.py

import os
PREFIX_KAGGLE_ROOT = os.environ.get('PREFIX_KAGGLE_ROOT')
if PREFIX_KAGGLE_ROOT is None:
    raise "Undefined PREFIX_KAGGLE_ROOT in ENV vars !!!"

import argparse
from glob import glob
import shutil
import json
import dataclasses

import numpy as np
import torch

from copy import deepcopy
from time import sleep

import gc
import sys
sys.path.append(f'{PREFIX_KAGGLE_ROOT}/kaggle/working/mast3r/')
from retrieval_processor import get_retriever_model, get_similarity_pairs
from mast3r_colmapdb_module import get_colmapdb_from_mast3r_matching
from imc25_prediction_utils import Prediction, save_predictions, load_predictions, write_to_submission_file
from imc25_subp_scheduler import SubProcessScheduler


def get_image_pairs_shortlist_mast3r_retrieval(fnames, top_k=30, topk_percentile=0.3, top_k_max=50, 
                                               sim_score_thres=0.0, include_symmetric=False,
                                               device=torch.device('cpu')):

    retriever = get_retriever_model(device=device)
    sim_matrix = retriever(fnames)

    pairs = get_similarity_pairs(sim_matrix,
                top_k=top_k,
                topk_percentile=topk_percentile,
                top_k_max = top_k_max,
                sim_score_thres=sim_score_thres,
                include_symmetric=include_symmetric,
                )

    return pairs




if __name__ == "__main__":

    parser = argparse.ArgumentParser(description="MASt3R Shortlist and Matching SubP")

    parser.add_argument("--device", type=str, default="cuda" if torch.cuda.is_available() else "cpu")
    parser.add_argument("--data_dir", type=str, required=True, help="Root Dir of all datasets")
    parser.add_argument("--io_dir", type=str, required=True, help="input output dir")
    parser.add_argument("--dataset_split", type=str, default="test", choices=["train", "test"], help="input output dir")
    parser.add_argument("--max_images", type=int, default=None, help="max images to load for debugging")

    args = parser.parse_args()

    dataset_samples = load_predictions(os.path.join(args.io_dir, "dataset_samples.json"))
    dataset_filename_to_index = {p.filename: idx for idx, p in enumerate(dataset_samples)}
    dataset = dataset_samples[0].dataset
    is_train = (args.dataset_split == "train")

    images_dir = os.path.join(args.data_dir, args.dataset_split, dataset)
    images = [os.path.join(images_dir, sample.filename) for sample in dataset_samples]
    if args.max_images is not None:
        images = images[:args.max_images]

    index_pairs = get_image_pairs_shortlist_mast3r_retrieval(
        images,
        device=args.device,
        top_k=10, topk_percentile=0.3, top_k_max=30,
        sim_score_thres=0.001, include_symmetric=False,
    )

    database_path, pairs_txt_path = get_colmapdb_from_mast3r_matching(outputdir=args.io_dir, filelist=images, pair_idxs_list=index_pairs,
                                        shared_intrinsics = False, image_square_ok=True, device=args.device)


    workdir = os.path.dirname(args.io_dir)
    conda_mamba_path = "/kaggle/working/miniconda/bin/conda"

    pycolmap_subp_scheduler = SubProcessScheduler(workdir=workdir, env_dict={"PREFIX_KAGGLE_ROOT": PREFIX_KAGGLE_ROOT},
        base_cmd=f"{conda_mamba_path} run -n mast3r_sfm python imc25_mast3r_pycolmap_subp.py --data_dir={args.data_dir} --dataset_split={'train' if is_train else 'test'} ".split(),
        datasets_to_process=[dataset], process_type="pycolmap", num_devices=1, num_subprocesses_per_device=1, max_retries=10, max_duration=10*3600, device_type="cpu",
        )
    
    pycolmap_subp_scheduler.run()
# Out:
# Writing imc25_mast3r_shortlist_matching_pycolmap_subp.py

# %%
# %%writefile imc25_mast3r_pycolmap_subp.py

import os
PREFIX_KAGGLE_ROOT = os.environ.get('PREFIX_KAGGLE_ROOT')
if PREFIX_KAGGLE_ROOT is None:
    raise "Undefined PREFIX_KAGGLE_ROOT in ENV vars !!!"

import argparse
from glob import glob
import shutil
import json
import dataclasses

import numpy as np
import pycolmap

from copy import deepcopy
from time import sleep
import gc

from imc25_prediction_utils import Prediction, save_predictions, load_predictions, write_to_submission_file


if __name__ == "__main__":

    parser = argparse.ArgumentParser(description="pycolmap subp")

    parser.add_argument("--data_dir", type=str, required=True, help="Root Dir of all datasets")
    parser.add_argument("--io_dir", type=str, required=True, help="input output dir")
    parser.add_argument("--dataset_split", type=str, default="test", choices=["train", "test"], help="input output dir")
    parser.add_argument("--max_images", type=int, default=None, help="max images to load for debugging")

    args = parser.parse_args()

    dataset_samples = load_predictions(os.path.join(args.io_dir, "dataset_samples.json"))
    dataset_filename_to_index = {p.filename: idx for idx, p in enumerate(dataset_samples)}
    dataset = dataset_samples[0].dataset

    images_dir = os.path.join(args.data_dir, args.dataset_split, dataset)
    images = [os.path.join(images_dir, sample.filename) for sample in dataset_samples]
    if args.max_images is not None:
        images = images[:args.max_images]

    database_path = os.path.join(args.io_dir, "colmap.db")
    pairs_txt_path = os.path.join(args.io_dir, "pairs.txt")

    matches_verified_indicator_file = os.path.join(args.io_dir, "matches_verified.txt")
    if not os.path.exists(matches_verified_indicator_file):
        pycolmap.verify_matches(database_path, pairs_txt_path)

    os.system(f'touch {matches_verified_indicator_file}')

    output_path = os.path.join(args.io_dir, 'colmap_rec_mast3r')
    if os.path.exists(output_path):
        shutil.rmtree(output_path)
    os.makedirs(output_path)


    # By default colmap does not generate a reconstruction if less than 10 images are registered.
    # Lower it to 3.
    mapper_options = pycolmap.IncrementalPipelineOptions()
    mapper_options.min_model_size = 3
    mapper_options.max_num_models = 25
    # mapper_options.num_threads = 1

    maps = pycolmap.incremental_mapping(
        database_path=database_path,
        image_path=images_dir,
        output_path=output_path,
        options=mapper_options)
    
    sleep(1)
    print(maps)


    registered = 0
    for map_index, cur_map in maps.items():
        for index, image in cur_map.images.items():
            prediction_index = dataset_filename_to_index[image.name]
            dataset_samples[prediction_index].cluster_index = map_index
            dataset_samples[prediction_index].rotation = deepcopy(image.cam_from_world.rotation.matrix())
            dataset_samples[prediction_index].translation = deepcopy(image.cam_from_world.translation)
            registered += 1
    

    mapping_result_str = f'Dataset "{dataset}" -> Registered {registered} / {len(images)} images with {len(maps)} clusters'
    print(mapping_result_str)

    gc.collect()

    save_predictions(dataset_samples, os.path.join(args.io_dir, "dataset_preds.json"))
# Out:
# Writing imc25_mast3r_pycolmap_subp.py

# %%
# %%writefile imc25_subp_scheduler.py

import os
import time
import subprocess
from typing import List, Optional
from imc25_prediction_utils import Prediction, save_predictions, load_predictions, write_to_submission_file


class SubProcessScheduler:
    
    def __init__(
        self,
        workdir: str,
        env_dict: dict,
        base_cmd: List[str],
        datasets_to_process: List[str],
        process_type: str, # matching or pycolmap or etc 
        num_devices: int = 1,
        num_subprocesses_per_device: int = 1,
        max_retries: int = 3,
        max_duration: int = 3600,
        device_type: str = "cpu",
        dataset_samples: Optional[dict] = None,
        dataset_preds: Optional[dict] = None,
        is_train: bool = False,
    ):
        
        self.workdir = workdir
        self.env_dict = env_dict
        self.base_cmd = base_cmd
        self.datasets_to_process = datasets_to_process
        self.num_devices = num_devices
        self.num_subprocesses_per_device = num_subprocesses_per_device
        self.max_retries = max_retries
        self.max_duration = max_duration
        self.device_type = device_type
        self.process_type = process_type
        self.dataset_samples = dataset_samples
        self.dataset_preds = dataset_preds
        self.is_train = is_train
        
        if device_type == "cpu":
            assert self.num_devices == 1
        elif device_type == "cuda":  # hardcoded requirements for now
            assert max_retries == 1
            assert dataset_samples is not None
        else:
            raise "Unknown Device Type !!!"

        # Internal state
        self._pending_datasets: List[str] = []
        self._retry_queue: dict[str, int] = {}  # dataset_name -> retry_count
        self._attempted_datasets: set[str] = set()
        self._final_failed_datasets: List[str] = []
        self._start_time: Optional[float] = None
        self._initialize_pending_list()

    def _initialize_pending_list(self):
        self._pending_datasets = self.datasets_to_process.copy()


    def launch_subprocess(self, dataset: str, process_type: str):
        
        io_dir = os.path.join(self.workdir, dataset)
        os.makedirs(io_dir, exist_ok=True)

        print(f"Launching {process_type} subprocess for dataset: '{dataset}', io_dir='{io_dir}'")

        subprocess_env = os.environ.copy()
        for env_var_key, env_var_val in self.env_dict.items():
            subprocess_env[env_var_key] = env_var_val

        # for now: cuda --> mast3r subp ; cpu --> pycolmap subp
        if self.device_type == "cuda":
            # hardcoded the requirements for mast3r matching subprocess here, later needs to be decoupled
            save_predictions(self.dataset_samples[dataset], os.path.join(io_dir, "dataset_samples.json"))
            device_for_curr_dataset = f"{self.datasets_to_process.index(dataset) % self.num_devices}"
            subprocess_env["CUDA_VISIBLE_DEVICES"] = device_for_curr_dataset            
            cmd = self.base_cmd + [f"--io_dir={io_dir}", f"--device=cuda:0"]

        else:
            cmd = self.base_cmd + [f"--io_dir={io_dir}"]

        stdout_path = os.path.join(io_dir, f"proc_{dataset}_{process_type}_log.txt")
        stdout_file = open(stdout_path, "w")

        p = subprocess.Popen(
            cmd,
            env=subprocess_env,
            stdout=stdout_file,
            stderr=stdout_file,
        )

        return p, stdout_file

    def run(self, external_start_time=None, submission_file=None):
        
        if self._start_time is None:
            if external_start_time is None:
                self._start_time = time.time()
            else:
                self._start_time = external_start_time
        else:
            # If run() is called more than once, reset internal state.
            self._start_time = time.time()
            self._retry_queue.clear()
            self._attempted_datasets.clear()
            self._final_failed_datasets.clear()
            self._initialize_pending_list()

        batch_size = self.num_devices * self.num_subprocesses_per_device

        while self._pending_datasets or self._retry_queue:
            subprocesses = []

            while self._pending_datasets and len(subprocesses) < batch_size:
                dataset = self._pending_datasets.pop(0)
                self._attempted_datasets.add(dataset)

                p, out_f = self.launch_subprocess(dataset, self.process_type)
                subprocesses.append((dataset, p, out_f))

            for dataset, p, out_f in subprocesses:
                p.wait()
                out_f.close()

                if p.returncode != 0:
                    print(f"[ERROR] {self.process_type} Subprocess for '{dataset}' failed with returncode={p.returncode}")
                    current_retry_count = self._retry_queue.get(dataset, 0) + 1
                    if current_retry_count < self.max_retries:
                        self._retry_queue[dataset] = current_retry_count
                        print(f"  → Scheduling retry #{current_retry_count} for '{dataset}'")
                    else:
                        print(f"[FAILURE] {self.process_type} Subprocess for '{dataset}' failed after {current_retry_count} attempts.")
                        self._final_failed_datasets.append(dataset)
                        self._retry_queue.pop(dataset, None)
                else:
                    self._retry_queue.pop(dataset, None)
                    print(f"[SUCCESS] {self.process_type} Subprocess for '{dataset}' processed successfully.")
                    dataset_pred_json_file = os.path.join(self.workdir, dataset, "dataset_preds.json")
                    if os.path.exists(dataset_pred_json_file) and self.dataset_preds is not None:
                        self.dataset_preds[dataset] = load_predictions(dataset_pred_json_file)
                        if submission_file is not None:
                            write_to_submission_file(submission_file, self.dataset_preds, self.is_train)
            
            retrying_now = [d for d in self._retry_queue.keys() if d not in self._pending_datasets]
            for d in retrying_now:
                self._pending_datasets.append(d)

            elapsed = time.time() - self._start_time
            all_tried_once = len(self._attempted_datasets) >= len(self.datasets_to_process)

            if elapsed > self.max_duration and all_tried_once:
                print(
                    f"\n Time limit of {self.max_duration}s reached "
                    f"and all datasets attempted at least once."
                )
                break

        if self._final_failed_datasets:
            print("\nDatasets that failed after maximum retries:")
            for ds in self._final_failed_datasets:
                print(f"  - {ds}")
        else:
            print("\nAll datasets processed successfully.")
# Out:
# Writing imc25_subp_scheduler.py

# %%
import sys
import os
import time
import gc
import numpy as np
import dataclasses
import pandas as pd
import shutil
import json
import subprocess
from typing import List, Optional
from copy import deepcopy

from imc25_prediction_utils import Prediction, save_predictions, load_predictions, write_to_submission_file, read_sample_submission_file
from imc25_subp_scheduler import SubProcessScheduler

# %%
test_dataset_dir = f'{PREFIX_KAGGLE_ROOT}/kaggle/input/image-matching-challenge-2025/test/'
is_competition = (len(os.listdir(test_dataset_dir)) > 2)
print(f"{is_competition=}")
# Out:
# is_competition=False

# %%
is_train = False
max_images = None  # Used For debugging only. Set to None to disable.
# max_images = 20

data_dir = f'{PREFIX_KAGGLE_ROOT}/kaggle/input/image-matching-challenge-2025'
workdir = f'{PREFIX_KAGGLE_ROOT}/kaggle/working/result/'

if os.path.exists(workdir):
    shutil.rmtree(workdir)
os.makedirs(workdir)

if is_train:
    sample_submission_csv = os.path.join(data_dir, 'train_labels.csv')
else:
    sample_submission_csv = os.path.join(data_dir, 'sample_submission.csv')

samples = read_sample_submission_file(sample_submission_csv, is_train)

for dataset in samples:
    print(f'Dataset "{dataset}" -> num_images={len(samples[dataset])}')


gc.collect()

if is_train:
    # max_images = 5

    # Note: When running on the training dataset, the notebook will hit the time limit and die. Use this filter to run on a few specific datasets.
    datasets_to_process = [
    	# New data.
    	# 'amy_gardens',
    	'ETs',
    	# 'fbk_vineyard',
    	'stairs',
    	# Data from IMC 2023 and 2024.
    	# 'imc2024_dioscuri_baalshamin',
    	# 'imc2023_theather_imc2024_church',
    	# 'imc2023_heritage',
    	# 'imc2023_haiper',
    	# 'imc2024_lizard_pond',
    	# Crowdsourced PhotoTourism data.
    	# 'pt_stpeters_stpauls',
    	# 'pt_brandenburg_british_buckingham',
    	# 'pt_piazzasanmarco_grandplace',
    	# 'pt_sacrecoeur_trevi_tajmahal',
    ]

else:
    datasets_to_process = [dataset for dataset in samples]


print()
# sort datasets acc to length
datasets_to_process = sorted(datasets_to_process, key=lambda dataset: len(samples[dataset]))
# for debug purposes
if not is_competition:
    datasets_to_process = [datasets_to_process[0]]
    

print(f"{datasets_to_process=}")
print("--"*30)

dataset_preds = deepcopy(samples)
# Out:
# Dataset "ETs" -> num_images=22
# Dataset "amy_gardens" -> num_images=200
# Dataset "fbk_vineyard" -> num_images=163
# Dataset "imc2023_haiper" -> num_images=54
# Dataset "imc2023_heritage" -> num_images=209
# Dataset "imc2023_theather_imc2024_church" -> num_images=76
# Dataset "imc2024_dioscuri_baalshamin" -> num_images=138
# Dataset "imc2024_lizard_pond" -> num_images=214
# Dataset "pt_brandenburg_british_buckingham" -> num_images=225
# Dataset "pt_piazzasanmarco_grandplace" -> num_images=168
# Dataset "pt_sacrecoeur_trevi_tajmahal" -> num_images=225
# Dataset "pt_stpeters_stpauls" -> num_images=200
# Dataset "stairs" -> num_images=51
#
# datasets_to_process=['ETs']
# ------------------------------------------------------------

# %%
conda_mamba_path = "/kaggle/working/miniconda/bin/conda"

mast3r_matching_subp_scheduler = SubProcessScheduler(workdir=workdir, env_dict={"PREFIX_KAGGLE_ROOT": PREFIX_KAGGLE_ROOT, "MPLBACKEND": "tkagg"},
     base_cmd=f"{conda_mamba_path} run -n mast3r_sfm python imc25_mast3r_shortlist_matching_pycolmap_subp.py --data_dir={data_dir} --dataset_split={'train' if is_train else 'test'} ".split(),
     datasets_to_process=datasets_to_process, dataset_samples=samples, dataset_preds=dataset_preds, process_type="matching",
     num_devices=2, num_subprocesses_per_device=1, max_retries=1, max_duration=10*3600, device_type="cuda",
     )

mast3r_matching_subp_scheduler.run(submission_file=SUBMISSION_FILE)
# Out:
# Launching matching subprocess for dataset: 'ETs', io_dir='/kaggle/working/result/ETs'
# [SUCCESS] matching Subprocess for 'ETs' processed successfully.
# Submission File written to :  /kaggle/working/submission.csv
#
# All datasets processed successfully.

# %%
# collect dataset_preds.json from each dataset io_dir

dataset_preds = deepcopy(samples)

for dataset in dataset_preds:
    dataset_pred_json_file = os.path.join(workdir, dataset, "dataset_preds.json")
    if os.path.exists(dataset_pred_json_file):
        dataset_preds[dataset] = load_predictions(dataset_pred_json_file)

write_to_submission_file(SUBMISSION_FILE, dataset_preds, is_train)
# Out:
# Submission File written to :  /kaggle/working/submission.csv

# %%
# for debug purposes
if not is_competition and not is_train:
    print("--"*40)
    print("[DEBUG]")
    if os.path.exists('/kaggle/working/result/ETs/proc_ETs_pycolmap_log.txt'):
        # !cat /kaggle/working/result/ETs/proc_ETs_pycolmap_log.txt
    else:
        print("ETs pycolmap log not found !!!")
    print("--"*40)
# Out:
# --------------------------------------------------------------------------------
# [DEBUG]
# I20250617 18:23:19.465921 131932378625600 misc.cc:44]
# ==============================================================================
# Feature matching
# ==============================================================================
# I20250617 18:23:19.466665 131932370232896 sift.cc:1432] Creating SIFT CPU feature matcher
# I20250617 18:23:19.466773 131932361840192 sift.cc:1432] Creating SIFT CPU feature matcher
# I20250617 18:23:19.466950 131932345054784 sift.cc:1432] Creating SIFT CPU feature matcher
# I20250617 18:23:19.467021 131932353447488 sift.cc:1432] Creating SIFT CPU feature matcher
# I20250617 18:23:19.467069 131932378625600 pairing.cc:742] Importing image pairs...
# I20250617 18:23:19.467320 131932378625600 pairing.cc:775] Matching block [1/1]
# I20250617 18:23:21.294299 131932378625600 feature_matching.cc:46] in 1.827s
# I20250617 18:23:21.299074 131932378625600 timer.cc:91] Elapsed time: 0.031 [minutes]
# I20250617 18:23:21.356667 131932658775872 incremental_pipeline.cc:237] Loading database
# I20250617 18:23:21.358011 131932658775872 database_cache.cc:66] Loading cameras...
# I20250617 18:23:21.358102 131932658775872 database_cache.cc:76]  22 in 0.000s
# I20250617 18:23:21.358128 131932658775872 database_cache.cc:84] Loading matches...
# I20250617 18:23:21.361245 131932658775872 database_cache.cc:89]  80 in 0.003s
# I20250617 18:23:21.361319 131932658775872 database_cache.cc:105] Loading images...
# I20250617 18:23:21.371700 131932658775872 database_cache.cc:153]  22 in 0.010s (connected 19)
# I20250617 18:23:21.371778 131932658775872 database_cache.cc:164] Loading pose priors...
# I20250617 18:23:21.371948 131932658775872 database_cache.cc:175]  0 in 0.000s
# I20250617 18:23:21.371966 131932658775872 database_cache.cc:184] Building correspondence graph...
# W20250617 18:23:21.375559 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2 in image_id=1 and point2D_idx=3 in image_id=2
# W20250617 18:23:21.376103 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=337 in image_id=1 and point2D_idx=339 in image_id=2
# W20250617 18:23:21.376141 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=352 in image_id=1 and point2D_idx=355 in image_id=2
# W20250617 18:23:21.376207 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=549 in image_id=1 and point2D_idx=553 in image_id=2
# W20250617 18:23:21.376316 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=956 in image_id=1 and point2D_idx=961 in image_id=2
# W20250617 18:23:21.376358 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1042 in image_id=1 and point2D_idx=1048 in image_id=2
# W20250617 18:23:21.376457 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1365 in image_id=1 and point2D_idx=1372 in image_id=2
# W20250617 18:23:21.376564 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1722 in image_id=1 and point2D_idx=1721 in image_id=2
# W20250617 18:23:21.376580 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1723 in image_id=1 and point2D_idx=1730 in image_id=2
# W20250617 18:23:21.376739 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2528 in image_id=1 and point2D_idx=2536 in image_id=2
# W20250617 18:23:21.376798 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2582 in image_id=1 and point2D_idx=2591 in image_id=2
# W20250617 18:23:21.377919 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2601 in image_id=1 and point2D_idx=2583 in image_id=2
# W20250617 18:23:21.377969 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2669 in image_id=1 and point2D_idx=2678 in image_id=2
# W20250617 18:23:21.378080 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3304 in image_id=1 and point2D_idx=3314 in image_id=2
# W20250617 18:23:21.378119 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3401 in image_id=1 and point2D_idx=3412 in image_id=2
# W20250617 18:23:21.378226 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=348 in image_id=1 and point2D_idx=389 in image_id=3
# W20250617 18:23:21.378290 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=420 in image_id=1 and point2D_idx=505 in image_id=3
# W20250617 18:23:21.378334 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=489 in image_id=1 and point2D_idx=624 in image_id=3
# W20250617 18:23:21.378353 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=490 in image_id=1 and point2D_idx=627 in image_id=3
# W20250617 18:23:21.378388 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=544 in image_id=1 and point2D_idx=712 in image_id=3
# W20250617 18:23:21.378477 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=829 in image_id=1 and point2D_idx=1057 in image_id=3
# W20250617 18:23:21.378515 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=963 in image_id=1 and point2D_idx=1144 in image_id=3
# W20250617 18:23:21.378621 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1373 in image_id=1 and point2D_idx=1301 in image_id=3
# W20250617 18:23:21.378648 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1375 in image_id=1 and point2D_idx=1305 in image_id=3
# W20250617 18:23:21.378678 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1381 in image_id=1 and point2D_idx=1279 in image_id=3
# W20250617 18:23:21.378731 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1580 in image_id=1 and point2D_idx=1502 in image_id=3
# W20250617 18:23:21.378790 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1749 in image_id=1 and point2D_idx=1696 in image_id=3
# W20250617 18:23:21.378817 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1804 in image_id=1 and point2D_idx=1775 in image_id=3
# W20250617 18:23:21.378862 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2042 in image_id=1 and point2D_idx=2078 in image_id=3
# W20250617 18:23:21.378924 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2651 in image_id=1 and point2D_idx=2521 in image_id=3
# W20250617 18:23:21.379043 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1816 in image_id=1 and point2D_idx=839 in image_id=4
# W20250617 18:23:21.379069 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2058 in image_id=1 and point2D_idx=973 in image_id=4
# W20250617 18:23:21.379151 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2409 in image_id=1 and point2D_idx=1232 in image_id=4
# W20250617 18:23:21.379214 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2563 in image_id=1 and point2D_idx=1368 in image_id=4
# W20250617 18:23:21.379235 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2644 in image_id=1 and point2D_idx=1435 in image_id=4
# W20250617 18:23:21.379317 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3919 in image_id=1 and point2D_idx=272 in image_id=5
# W20250617 18:23:21.379371 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=827 in image_id=1 and point2D_idx=692 in image_id=5
# W20250617 18:23:21.379423 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1294 in image_id=1 and point2D_idx=1108 in image_id=5
# W20250617 18:23:21.379435 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1298 in image_id=1 and point2D_idx=1115 in image_id=5
# W20250617 18:23:21.379471 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1662 in image_id=1 and point2D_idx=1362 in image_id=5
# W20250617 18:23:21.379509 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1801 in image_id=1 and point2D_idx=1468 in image_id=5
# W20250617 18:23:21.379593 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2299 in image_id=1 and point2D_idx=1912 in image_id=5
# W20250617 18:23:21.379658 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2465 in image_id=1 and point2D_idx=2115 in image_id=5
# W20250617 18:23:21.379736 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2670 in image_id=1 and point2D_idx=2314 in image_id=5
# W20250617 18:23:21.379822 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2927 in image_id=1 and point2D_idx=2603 in image_id=5
# W20250617 18:23:21.379883 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3388 in image_id=1 and point2D_idx=3035 in image_id=5
# W20250617 18:23:21.379913 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8228 in image_id=1 and point2D_idx=3240 in image_id=5
# W20250617 18:23:21.379940 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=266 in image_id=1 and point2D_idx=96 in image_id=6
# W20250617 18:23:21.379966 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=357 in image_id=1 and point2D_idx=167 in image_id=6
# W20250617 18:23:21.380017 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8545 in image_id=1 and point2D_idx=548 in image_id=6
# W20250617 18:23:21.380064 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1381 in image_id=1 and point2D_idx=786 in image_id=6
# W20250617 18:23:21.380090 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1454 in image_id=1 and point2D_idx=829 in image_id=6
# W20250617 18:23:21.380106 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1528 in image_id=1 and point2D_idx=878 in image_id=6
# W20250617 18:23:21.380129 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8758 in image_id=1 and point2D_idx=965 in image_id=6
# W20250617 18:23:21.380152 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8786 in image_id=1 and point2D_idx=1035 in image_id=6
# W20250617 18:23:21.380172 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1820 in image_id=1 and point2D_idx=1095 in image_id=6
# W20250617 18:23:21.380206 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5000 in image_id=1 and point2D_idx=1247 in image_id=6
# W20250617 18:23:21.380241 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2113 in image_id=1 and point2D_idx=1284 in image_id=6
# W20250617 18:23:21.380275 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2275 in image_id=1 and point2D_idx=1383 in image_id=6
# W20250617 18:23:21.380302 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2297 in image_id=1 and point2D_idx=1399 in image_id=6
# W20250617 18:23:21.380326 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8971 in image_id=1 and point2D_idx=1403 in image_id=6
# W20250617 18:23:21.380352 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5180 in image_id=1 and point2D_idx=1420 in image_id=6
# W20250617 18:23:21.380379 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2446 in image_id=1 and point2D_idx=1530 in image_id=6
# W20250617 18:23:21.380401 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7513 in image_id=1 and point2D_idx=1552 in image_id=6
# W20250617 18:23:21.380476 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2863 in image_id=1 and point2D_idx=1918 in image_id=6
# W20250617 18:23:21.380505 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9315 in image_id=1 and point2D_idx=2066 in image_id=6
# W20250617 18:23:21.380530 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3073 in image_id=1 and point2D_idx=2110 in image_id=6
# W20250617 18:23:21.380547 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9382 in image_id=1 and point2D_idx=2162 in image_id=6
# W20250617 18:23:21.380578 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9463 in image_id=1 and point2D_idx=2305 in image_id=6
# W20250617 18:23:21.380596 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3326 in image_id=1 and point2D_idx=2335 in image_id=6
# W20250617 18:23:21.380630 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3514 in image_id=1 and point2D_idx=2482 in image_id=6
# W20250617 18:23:21.380657 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9626 in image_id=1 and point2D_idx=2595 in image_id=6
# W20250617 18:23:21.380694 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=414 in image_id=1 and point2D_idx=138 in image_id=7
# W20250617 18:23:21.380789 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=958 in image_id=1 and point2D_idx=400 in image_id=7
# W20250617 18:23:21.380885 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1313 in image_id=1 and point2D_idx=528 in image_id=7
# W20250617 18:23:21.380907 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1366 in image_id=1 and point2D_idx=550 in image_id=7
# W20250617 18:23:21.380940 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1585 in image_id=1 and point2D_idx=687 in image_id=7
# W20250617 18:23:21.380956 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9991 in image_id=1 and point2D_idx=699 in image_id=7
# W20250617 18:23:21.380973 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1649 in image_id=1 and point2D_idx=740 in image_id=7
# W20250617 18:23:21.380986 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1651 in image_id=1 and point2D_idx=743 in image_id=7
# W20250617 18:23:21.381008 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1724 in image_id=1 and point2D_idx=804 in image_id=7
# W20250617 18:23:21.381032 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1802 in image_id=1 and point2D_idx=875 in image_id=7
# W20250617 18:23:21.381045 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1815 in image_id=1 and point2D_idx=893 in image_id=7
# W20250617 18:23:21.381088 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2039 in image_id=1 and point2D_idx=1080 in image_id=7
# W20250617 18:23:21.381103 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=10190 in image_id=1 and point2D_idx=1104 in image_id=7
# W20250617 18:23:21.381126 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2205 in image_id=1 and point2D_idx=1197 in image_id=7
# W20250617 18:23:21.381192 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2446 in image_id=1 and point2D_idx=1317 in image_id=7
# W20250617 18:23:21.381233 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=10312 in image_id=1 and point2D_idx=1368 in image_id=7
# W20250617 18:23:21.381261 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2567 in image_id=1 and point2D_idx=1405 in image_id=7
# W20250617 18:23:21.381304 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2716 in image_id=1 and point2D_idx=1531 in image_id=7
# W20250617 18:23:21.381342 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2776 in image_id=1 and point2D_idx=1601 in image_id=7
# W20250617 18:23:21.381367 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2851 in image_id=1 and point2D_idx=1668 in image_id=7
# W20250617 18:23:21.381442 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=201 in image_id=1 and point2D_idx=37 in image_id=8
# W20250617 18:23:21.381476 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=757 in image_id=1 and point2D_idx=217 in image_id=8
# W20250617 18:23:21.381514 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1512 in image_id=1 and point2D_idx=375 in image_id=8
# W20250617 18:23:21.381544 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1652 in image_id=1 and point2D_idx=448 in image_id=8
# W20250617 18:23:21.381583 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2054 in image_id=1 and point2D_idx=658 in image_id=8
# W20250617 18:23:21.381595 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=11037 in image_id=1 and point2D_idx=670 in image_id=8
# W20250617 18:23:21.381639 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2642 in image_id=1 and point2D_idx=878 in image_id=8
# W20250617 18:23:21.381658 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2738 in image_id=1 and point2D_idx=930 in image_id=8
# W20250617 18:23:21.381684 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2769 in image_id=1 and point2D_idx=948 in image_id=8
# W20250617 18:23:21.381723 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3304 in image_id=1 and point2D_idx=1123 in image_id=8
# W20250617 18:23:21.381739 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3384 in image_id=1 and point2D_idx=1138 in image_id=8
# W20250617 18:23:21.381818 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1805 in image_id=1 and point2D_idx=1219 in image_id=9
# W20250617 18:23:21.381835 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1808 in image_id=1 and point2D_idx=1205 in image_id=9
# W20250617 18:23:21.381866 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2224 in image_id=1 and point2D_idx=1163 in image_id=9
# W20250617 18:23:21.381880 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2301 in image_id=1 and point2D_idx=1175 in image_id=9
# W20250617 18:23:21.381925 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2640 in image_id=1 and point2D_idx=1666 in image_id=9
# W20250617 18:23:21.381947 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9199 in image_id=1 and point2D_idx=1793 in image_id=9
# W20250617 18:23:21.381963 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2849 in image_id=1 and point2D_idx=768 in image_id=9
# W20250617 18:23:21.382018 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3330 in image_id=1 and point2D_idx=1301 in image_id=9
# W20250617 18:23:21.382078 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2144 in image_id=1 and point2D_idx=3254 in image_id=10
# W20250617 18:23:21.382113 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2562 in image_id=1 and point2D_idx=191 in image_id=10
# W20250617 18:23:21.382185 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3396 in image_id=1 and point2D_idx=3326 in image_id=10
# W20250617 18:23:21.382198 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=12053 in image_id=1 and point2D_idx=3393 in image_id=10
# W20250617 18:23:21.382255 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=161 in image_id=2 and point2D_idx=2656 in image_id=3
# W20250617 18:23:21.382299 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=293 in image_id=2 and point2D_idx=2720 in image_id=3
# W20250617 18:23:21.382432 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=810 in image_id=2 and point2D_idx=1014 in image_id=3
# W20250617 18:23:21.382491 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1403 in image_id=2 and point2D_idx=3071 in image_id=3
# W20250617 18:23:21.382566 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1622 in image_id=2 and point2D_idx=3208 in image_id=3
# W20250617 18:23:21.382586 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1640 in image_id=2 and point2D_idx=3216 in image_id=3
# W20250617 18:23:21.382691 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=4958 in image_id=2 and point2D_idx=2126 in image_id=3
# W20250617 18:23:21.382725 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2152 in image_id=2 and point2D_idx=3496 in image_id=3
# W20250617 18:23:21.382798 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2609 in image_id=2 and point2D_idx=2495 in image_id=3
# W20250617 18:23:21.382819 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2657 in image_id=2 and point2D_idx=3662 in image_id=3
# W20250617 18:23:21.382871 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5385 in image_id=2 and point2D_idx=1758 in image_id=4
# W20250617 18:23:21.382885 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=292 in image_id=2 and point2D_idx=1812 in image_id=4
# W20250617 18:23:21.382909 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=347 in image_id=2 and point2D_idx=1880 in image_id=4
# W20250617 18:23:21.382953 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=510 in image_id=2 and point2D_idx=2073 in image_id=4
# W20250617 18:23:21.383033 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=783 in image_id=2 and point2D_idx=2404 in image_id=4
# W20250617 18:23:21.383082 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=938 in image_id=2 and point2D_idx=2576 in image_id=4
# W20250617 18:23:21.383140 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1188 in image_id=2 and point2D_idx=2789 in image_id=4
# W20250617 18:23:21.383159 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1254 in image_id=2 and point2D_idx=2839 in image_id=4
# W20250617 18:23:21.383209 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1643 in image_id=2 and point2D_idx=3086 in image_id=4
# W20250617 18:23:21.383226 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=4646 in image_id=2 and point2D_idx=3125 in image_id=4
# W20250617 18:23:21.383237 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1691 in image_id=2 and point2D_idx=3146 in image_id=4
# W20250617 18:23:21.383279 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1845 in image_id=2 and point2D_idx=3240 in image_id=4
# W20250617 18:23:21.383297 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1874 in image_id=2 and point2D_idx=3276 in image_id=4
# W20250617 18:23:21.383320 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1891 in image_id=2 and point2D_idx=3313 in image_id=4
# W20250617 18:23:21.383352 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2087 in image_id=2 and point2D_idx=987 in image_id=4
# W20250617 18:23:21.383382 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2241 in image_id=2 and point2D_idx=3509 in image_id=4
# W20250617 18:23:21.383422 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2381 in image_id=2 and point2D_idx=3626 in image_id=4
# W20250617 18:23:21.383435 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2384 in image_id=2 and point2D_idx=3633 in image_id=4
# W20250617 18:23:21.383502 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2696 in image_id=2 and point2D_idx=3854 in image_id=4
# W20250617 18:23:21.383598 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=524 in image_id=2 and point2D_idx=3401 in image_id=5
# W20250617 18:23:21.383691 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=995 in image_id=2 and point2D_idx=869 in image_id=5
# W20250617 18:23:21.383870 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2610 in image_id=2 and point2D_idx=2251 in image_id=5
# W20250617 18:23:21.384024 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8873 in image_id=2 and point2D_idx=2598 in image_id=6
# W20250617 18:23:21.384120 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=750 in image_id=2 and point2D_idx=452 in image_id=6
# W20250617 18:23:21.384160 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9181 in image_id=2 and point2D_idx=729 in image_id=6
# W20250617 18:23:21.384190 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=4381 in image_id=2 and point2D_idx=791 in image_id=6
# W20250617 18:23:21.384241 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1687 in image_id=2 and point2D_idx=3168 in image_id=6
# W20250617 18:23:21.384274 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1830 in image_id=2 and point2D_idx=1097 in image_id=6
# W20250617 18:23:21.384322 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9448 in image_id=2 and point2D_idx=3313 in image_id=6
# W20250617 18:23:21.384394 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2556 in image_id=2 and point2D_idx=3517 in image_id=6
# W20250617 18:23:21.384442 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2562 in image_id=2 and point2D_idx=1660 in image_id=6
# W20250617 18:23:21.384491 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2920 in image_id=2 and point2D_idx=3783 in image_id=6
# W20250617 18:23:21.384541 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9944 in image_id=2 and point2D_idx=2220 in image_id=6
# W20250617 18:23:21.384562 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3260 in image_id=2 and point2D_idx=2269 in image_id=6
# W20250617 18:23:21.384601 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=10046 in image_id=2 and point2D_idx=2426 in image_id=6
# W20250617 18:23:21.384708 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=11035 in image_id=2 and point2D_idx=373 in image_id=7
# W20250617 18:23:21.384795 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1718 in image_id=2 and point2D_idx=789 in image_id=7
# W20250617 18:23:21.384816 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1483 in image_id=2 and point2D_idx=619 in image_id=7
# W20250617 18:23:21.384842 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1639 in image_id=2 and point2D_idx=720 in image_id=7
# W20250617 18:23:21.384855 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=11181 in image_id=2 and point2D_idx=699 in image_id=7
# W20250617 18:23:21.384874 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1687 in image_id=2 and point2D_idx=769 in image_id=7
# W20250617 18:23:21.384894 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1725 in image_id=2 and point2D_idx=798 in image_id=7
# W20250617 18:23:21.384915 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1793 in image_id=2 and point2D_idx=4141 in image_id=7
# W20250617 18:23:21.384959 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=11381 in image_id=2 and point2D_idx=1107 in image_id=7
# W20250617 18:23:21.384981 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=11360 in image_id=2 and point2D_idx=1169 in image_id=7
# W20250617 18:23:21.385002 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=11339 in image_id=2 and point2D_idx=1170 in image_id=7
# W20250617 18:23:21.385032 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2505 in image_id=2 and point2D_idx=4447 in image_id=7
# W20250617 18:23:21.385045 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=11450 in image_id=2 and point2D_idx=1307 in image_id=7
# W20250617 18:23:21.385077 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2600 in image_id=2 and point2D_idx=1432 in image_id=7
# W20250617 18:23:21.385092 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=11620 in image_id=2 and point2D_idx=1380 in image_id=7
# W20250617 18:23:21.385116 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2574 in image_id=2 and point2D_idx=1405 in image_id=7
# W20250617 18:23:21.385136 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2622 in image_id=2 and point2D_idx=4532 in image_id=7
# W20250617 18:23:21.385153 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=11649 in image_id=2 and point2D_idx=1452 in image_id=7
# W20250617 18:23:21.385192 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2851 in image_id=2 and point2D_idx=1796 in image_id=7
# W20250617 18:23:21.385226 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3012 in image_id=2 and point2D_idx=1771 in image_id=7
# W20250617 18:23:21.385239 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3043 in image_id=2 and point2D_idx=4301 in image_id=7
# W20250617 18:23:21.385265 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3114 in image_id=2 and point2D_idx=1836 in image_id=7
# W20250617 18:23:21.385300 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3297 in image_id=2 and point2D_idx=1945 in image_id=7
# W20250617 18:23:21.385324 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3360 in image_id=2 and point2D_idx=4462 in image_id=7
# W20250617 18:23:21.385393 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=857 in image_id=2 and point2D_idx=1322 in image_id=8
# W20250617 18:23:21.385420 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=12121 in image_id=2 and point2D_idx=1324 in image_id=8
# W20250617 18:23:21.385445 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1404 in image_id=2 and point2D_idx=1382 in image_id=8
# W20250617 18:23:21.385462 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=12168 in image_id=2 and point2D_idx=1412 in image_id=8
# W20250617 18:23:21.385477 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=12167 in image_id=2 and point2D_idx=367 in image_id=8
# W20250617 18:23:21.385506 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1793 in image_id=2 and point2D_idx=1680 in image_id=8
# W20250617 18:23:21.385591 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2677 in image_id=2 and point2D_idx=867 in image_id=8
# W20250617 18:23:21.385627 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2976 in image_id=2 and point2D_idx=1796 in image_id=8
# W20250617 18:23:21.385655 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3051 in image_id=2 and point2D_idx=1042 in image_id=8
# W20250617 18:23:21.385698 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3208 in image_id=2 and point2D_idx=1087 in image_id=8
# W20250617 18:23:21.385738 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=12634 in image_id=2 and point2D_idx=2209 in image_id=8
# W20250617 18:23:21.385791 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=805 in image_id=2 and point2D_idx=118 in image_id=9
# W20250617 18:23:21.385808 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=879 in image_id=2 and point2D_idx=135 in image_id=9
# W20250617 18:23:21.385830 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1503 in image_id=2 and point2D_idx=234 in image_id=9
# W20250617 18:23:21.385850 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1617 in image_id=2 and point2D_idx=295 in image_id=9
# W20250617 18:23:21.385877 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1960 in image_id=2 and point2D_idx=404 in image_id=9
# W20250617 18:23:21.385932 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2781 in image_id=2 and point2D_idx=728 in image_id=9
# W20250617 18:23:21.386001 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2505 in image_id=2 and point2D_idx=153 in image_id=10
# W20250617 18:23:21.386047 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3323 in image_id=2 and point2D_idx=424 in image_id=10
# W20250617 18:23:21.386060 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=10792 in image_id=2 and point2D_idx=441 in image_id=10
# W20250617 18:23:21.386158 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3915 in image_id=3 and point2D_idx=125 in image_id=4
# W20250617 18:23:21.386204 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=4017 in image_id=3 and point2D_idx=1916 in image_id=4
# W20250617 18:23:21.386267 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=763 in image_id=3 and point2D_idx=2168 in image_id=4
# W20250617 18:23:21.386284 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=4187 in image_id=3 and point2D_idx=2174 in image_id=4
# W20250617 18:23:21.386303 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=799 in image_id=3 and point2D_idx=2227 in image_id=4
# W20250617 18:23:21.386344 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1009 in image_id=3 and point2D_idx=2382 in image_id=4
# W20250617 18:23:21.386373 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=4336 in image_id=3 and point2D_idx=2485 in image_id=4
# W20250617 18:23:21.386387 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1088 in image_id=3 and point2D_idx=4733 in image_id=4
# W20250617 18:23:21.386439 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1461 in image_id=3 and point2D_idx=4894 in image_id=4
# W20250617 18:23:21.386479 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3188 in image_id=3 and point2D_idx=5008 in image_id=4
# W20250617 18:23:21.386692 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3557 in image_id=3 and point2D_idx=5610 in image_id=4
# W20250617 18:23:21.386708 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5192 in image_id=3 and point2D_idx=1084 in image_id=4
# W20250617 18:23:21.386738 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5421 in image_id=3 and point2D_idx=5249 in image_id=5
# W20250617 18:23:21.386789 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5493 in image_id=3 and point2D_idx=225 in image_id=5
# W20250617 18:23:21.386811 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=451 in image_id=3 and point2D_idx=251 in image_id=5
# W20250617 18:23:21.386837 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5572 in image_id=3 and point2D_idx=420 in image_id=5
# W20250617 18:23:21.386892 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5266 in image_id=3 and point2D_idx=224 in image_id=5
# W20250617 18:23:21.386908 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5272 in image_id=3 and point2D_idx=242 in image_id=5
# W20250617 18:23:21.386927 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5824 in image_id=3 and point2D_idx=1171 in image_id=5
# W20250617 18:23:21.386971 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5376 in image_id=3 and point2D_idx=510 in image_id=5
# W20250617 18:23:21.387009 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1080 in image_id=3 and point2D_idx=5361 in image_id=5
# W20250617 18:23:21.387022 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1032 in image_id=3 and point2D_idx=670 in image_id=5
# W20250617 18:23:21.387058 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1328 in image_id=3 and point2D_idx=1190 in image_id=5
# W20250617 18:23:21.387099 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5861 in image_id=3 and point2D_idx=1335 in image_id=5
# W20250617 18:23:21.387123 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1735 in image_id=3 and point2D_idx=1449 in image_id=5
# W20250617 18:23:21.387145 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1732 in image_id=3 and point2D_idx=1442 in image_id=5
# W20250617 18:23:21.387161 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1838 in image_id=3 and point2D_idx=1521 in image_id=5
# W20250617 18:23:21.387183 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5957 in image_id=3 and point2D_idx=1501 in image_id=5
# W20250617 18:23:21.387215 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6075 in image_id=3 and point2D_idx=1705 in image_id=5
# W20250617 18:23:21.387238 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2136 in image_id=3 and point2D_idx=1720 in image_id=5
# W20250617 18:23:21.387250 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1932 in image_id=3 and point2D_idx=1581 in image_id=5
# W20250617 18:23:21.387290 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6036 in image_id=3 and point2D_idx=1660 in image_id=5
# W20250617 18:23:21.387312 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6218 in image_id=3 and point2D_idx=2051 in image_id=5
# W20250617 18:23:21.387326 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2141 in image_id=3 and point2D_idx=1722 in image_id=5
# W20250617 18:23:21.387406 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=812 in image_id=3 and point2D_idx=6044 in image_id=6
# W20250617 18:23:21.387436 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3837 in image_id=3 and point2D_idx=5985 in image_id=6
# W20250617 18:23:21.387460 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6432 in image_id=3 and point2D_idx=84 in image_id=6
# W20250617 18:23:21.387546 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=647 in image_id=3 and point2D_idx=299 in image_id=6
# W20250617 18:23:21.387562 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6532 in image_id=3 and point2D_idx=300 in image_id=6
# W20250617 18:23:21.387575 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=4148 in image_id=3 and point2D_idx=397 in image_id=6
# W20250617 18:23:21.387616 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6588 in image_id=3 and point2D_idx=442 in image_id=6
# W20250617 18:23:21.387673 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6700 in image_id=3 and point2D_idx=837 in image_id=6
# W20250617 18:23:21.387715 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1633 in image_id=3 and point2D_idx=999 in image_id=6
# W20250617 18:23:21.387765 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1809 in image_id=3 and point2D_idx=1105 in image_id=6
# W20250617 18:23:21.387791 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1868 in image_id=3 and point2D_idx=1122 in image_id=6
# W20250617 18:23:21.387858 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6966 in image_id=3 and point2D_idx=1343 in image_id=6
# W20250617 18:23:21.387870 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6929 in image_id=3 and point2D_idx=1447 in image_id=6
# W20250617 18:23:21.387902 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2424 in image_id=3 and point2D_idx=1555 in image_id=6
# W20250617 18:23:21.387914 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2443 in image_id=3 and point2D_idx=1569 in image_id=6
# W20250617 18:23:21.387969 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7060 in image_id=3 and point2D_idx=38 in image_id=7
# W20250617 18:23:21.387984 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7061 in image_id=3 and point2D_idx=49 in image_id=7
# W20250617 18:23:21.388014 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=332 in image_id=3 and point2D_idx=96 in image_id=7
# W20250617 18:23:21.388033 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=384 in image_id=3 and point2D_idx=109 in image_id=7
# W20250617 18:23:21.388064 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=531 in image_id=3 and point2D_idx=158 in image_id=7
# W20250617 18:23:21.388090 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=653 in image_id=3 and point2D_idx=203 in image_id=7
# W20250617 18:23:21.388118 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7178 in image_id=3 and point2D_idx=278 in image_id=7
# W20250617 18:23:21.388132 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7189 in image_id=3 and point2D_idx=306 in image_id=7
# W20250617 18:23:21.388168 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7245 in image_id=3 and point2D_idx=508 in image_id=7
# W20250617 18:23:21.388189 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1322 in image_id=3 and point2D_idx=2558 in image_id=7
# W20250617 18:23:21.388219 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7411 in image_id=3 and point2D_idx=723 in image_id=7
# W20250617 18:23:21.388231 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1533 in image_id=3 and point2D_idx=720 in image_id=7
# W20250617 18:23:21.388269 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7381 in image_id=3 and point2D_idx=788 in image_id=7
# W20250617 18:23:21.388289 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1748 in image_id=3 and point2D_idx=852 in image_id=7
# W20250617 18:23:21.388340 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7504 in image_id=3 and point2D_idx=4169 in image_id=7
# W20250617 18:23:21.388362 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2330 in image_id=3 and point2D_idx=1255 in image_id=7
# W20250617 18:23:21.388397 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7573 in image_id=3 and point2D_idx=1565 in image_id=7
# W20250617 18:23:21.388418 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7582 in image_id=3 and point2D_idx=1632 in image_id=7
# W20250617 18:23:21.388442 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7598 in image_id=3 and point2D_idx=60 in image_id=8
# ...
# W20250617 18:23:21.414650 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7347 in image_id=16 and point2D_idx=6066 in image_id=17
# W20250617 18:23:21.414821 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=175 in image_id=16 and point2D_idx=199 in image_id=17
# W20250617 18:23:21.414940 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7553 in image_id=16 and point2D_idx=536 in image_id=17
# W20250617 18:23:21.414979 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7689 in image_id=16 and point2D_idx=2203 in image_id=17
# W20250617 18:23:21.415155 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8263 in image_id=16 and point2D_idx=5112 in image_id=17
# W20250617 18:23:21.415493 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5184 in image_id=16 and point2D_idx=1302 in image_id=18
# W20250617 18:23:21.415521 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5229 in image_id=16 and point2D_idx=5225 in image_id=18
# W20250617 18:23:21.415619 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2807 in image_id=16 and point2D_idx=1459 in image_id=18
# W20250617 18:23:21.415636 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9503 in image_id=16 and point2D_idx=31 in image_id=18
# W20250617 18:23:21.415675 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7718 in image_id=16 and point2D_idx=5829 in image_id=18
# W20250617 18:23:21.415740 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7969 in image_id=16 and point2D_idx=6081 in image_id=18
# W20250617 18:23:21.415831 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5709 in image_id=16 and point2D_idx=5903 in image_id=18
# W20250617 18:23:21.415955 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=10221 in image_id=16 and point2D_idx=658 in image_id=18
# W20250617 18:23:21.416279 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2387 in image_id=16 and point2D_idx=818 in image_id=18
# W20250617 18:23:21.416299 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5134 in image_id=16 and point2D_idx=3597 in image_id=19
# W20250617 18:23:21.416319 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5196 in image_id=16 and point2D_idx=3663 in image_id=19
# W20250617 18:23:21.416342 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5243 in image_id=16 and point2D_idx=3710 in image_id=19
# W20250617 18:23:21.416357 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5294 in image_id=16 and point2D_idx=3764 in image_id=19
# W20250617 18:23:21.416383 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5318 in image_id=16 and point2D_idx=3812 in image_id=19
# W20250617 18:23:21.416446 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5499 in image_id=16 and point2D_idx=4079 in image_id=19
# W20250617 18:23:21.416484 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5532 in image_id=16 and point2D_idx=4115 in image_id=19
# W20250617 18:23:21.416551 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5755 in image_id=16 and point2D_idx=4395 in image_id=19
# W20250617 18:23:21.416585 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5842 in image_id=16 and point2D_idx=1845 in image_id=19
# W20250617 18:23:21.416609 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5883 in image_id=16 and point2D_idx=1860 in image_id=19
# W20250617 18:23:21.416656 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=4570 in image_id=16 and point2D_idx=1250 in image_id=19
# W20250617 18:23:21.416728 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6283 in image_id=16 and point2D_idx=212 in image_id=19
# W20250617 18:23:21.416746 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3234 in image_id=16 and point2D_idx=5055 in image_id=19
# W20250617 18:23:21.416809 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6368 in image_id=16 and point2D_idx=370 in image_id=19
# W20250617 18:23:21.416830 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6376 in image_id=16 and point2D_idx=5137 in image_id=19
# W20250617 18:23:21.416970 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=1067 in image_id=16 and point2D_idx=655 in image_id=19
# W20250617 18:23:21.416991 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6810 in image_id=16 and point2D_idx=1661 in image_id=19
# W20250617 18:23:21.417034 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=6897 in image_id=16 and point2D_idx=535 in image_id=19
# W20250617 18:23:21.417237 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=4209 in image_id=17 and point2D_idx=8273 in image_id=18
# W20250617 18:23:21.417280 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=408 in image_id=17 and point2D_idx=8318 in image_id=18
# W20250617 18:23:21.417401 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=598 in image_id=17 and point2D_idx=516 in image_id=18
# W20250617 18:23:21.417609 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7574 in image_id=17 and point2D_idx=7245 in image_id=18
# W20250617 18:23:21.417623 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=3635 in image_id=17 and point2D_idx=2253 in image_id=18
# W20250617 18:23:21.417898 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5833 in image_id=17 and point2D_idx=5982 in image_id=19
# W20250617 18:23:21.417946 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8457 in image_id=17 and point2D_idx=3698 in image_id=19
# W20250617 18:23:21.417971 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=439 in image_id=17 and point2D_idx=91 in image_id=19
# W20250617 18:23:21.418078 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=622 in image_id=17 and point2D_idx=6427 in image_id=19
# W20250617 18:23:21.418098 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7050 in image_id=17 and point2D_idx=4453 in image_id=19
# W20250617 18:23:21.418111 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2384 in image_id=17 and point2D_idx=2054 in image_id=19
# W20250617 18:23:21.418140 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8867 in image_id=17 and point2D_idx=4842 in image_id=19
# W20250617 18:23:21.418162 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7130 in image_id=17 and point2D_idx=6494 in image_id=19
# W20250617 18:23:21.418178 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=7181 in image_id=17 and point2D_idx=4561 in image_id=19
# W20250617 18:23:21.418221 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=775 in image_id=17 and point2D_idx=6622 in image_id=19
# W20250617 18:23:21.418289 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2491 in image_id=17 and point2D_idx=6826 in image_id=19
# W20250617 18:23:21.418306 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=9205 in image_id=17 and point2D_idx=1397 in image_id=19
# W20250617 18:23:21.418422 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5169 in image_id=18 and point2D_idx=3721 in image_id=19
# W20250617 18:23:21.418438 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=8075 in image_id=18 and point2D_idx=3929 in image_id=19
# W20250617 18:23:21.418470 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5400 in image_id=18 and point2D_idx=7200 in image_id=19
# W20250617 18:23:21.418494 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=5599 in image_id=18 and point2D_idx=4173 in image_id=19
# W20250617 18:23:21.418576 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=10287 in image_id=18 and point2D_idx=3033 in image_id=19
# W20250617 18:23:21.418631 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=519 in image_id=18 and point2D_idx=182 in image_id=19
# W20250617 18:23:21.418656 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=10445 in image_id=18 and point2D_idx=4841 in image_id=19
# W20250617 18:23:21.418716 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=2153 in image_id=18 and point2D_idx=7766 in image_id=19
# W20250617 18:23:21.418892 131932658775872 correspondence_graph.cc:156] Duplicate correspondence between point2D_idx=853 in image_id=18 and point2D_idx=503 in image_id=19
# I20250617 18:23:21.433690 131932658775872 database_cache.cc:210]  in 0.062s (ignored 0)
# I20250617 18:23:21.433784 131932658775872 timer.cc:91] Elapsed time: 0.001 [minutes]
# I20250617 18:23:21.436037 131932658775872 incremental_pipeline.cc:282] Finding good initial image pair
# I20250617 18:23:21.937026 131932658775872 incremental_pipeline.cc:306] Initializing with image pair #12 and #16
# I20250617 18:23:21.943893 131932658775872 incremental_pipeline.cc:311] Global bundle adjustment
# I20250617 18:23:22.881820 131932658775872 incremental_pipeline.cc:390] Registering image #17 (3)
# I20250617 18:23:22.881861 131932658775872 incremental_pipeline.cc:393] => Image sees 1418 / 11265 points
# I20250617 18:23:24.365213 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:23:24.694158 131932658775872 incremental_pipeline.cc:390] Registering image #18 (4)
# I20250617 18:23:24.694200 131932658775872 incremental_pipeline.cc:393] => Image sees 4780 / 11108 points
# I20250617 18:23:26.359608 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:23:26.878845 131932658775872 incremental_pipeline.cc:390] Registering image #19 (5)
# I20250617 18:23:26.878888 131932658775872 incremental_pipeline.cc:393] => Image sees 4663 / 8242 points
# I20250617 18:23:29.040246 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:23:29.676098 131932658775872 incremental_pipeline.cc:390] Registering image #15 (6)
# I20250617 18:23:29.676194 131932658775872 incremental_pipeline.cc:393] => Image sees 4213 / 11700 points
# I20250617 18:23:33.392994 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:23:34.379423 131932658775872 incremental_pipeline.cc:390] Registering image #13 (7)
# I20250617 18:23:34.379469 131932658775872 incremental_pipeline.cc:393] => Image sees 7876 / 13525 points
# I20250617 18:23:39.283659 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:23:40.907323 131932658775872 incremental_pipeline.cc:390] Registering image #11 (8)
# I20250617 18:23:40.907376 131932658775872 incremental_pipeline.cc:393] => Image sees 7994 / 12458 points
# I20250617 18:23:44.909599 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:23:47.303863 131932658775872 incremental_pipeline.cc:390] Registering image #14 (9)
# I20250617 18:23:47.303917 131932658775872 incremental_pipeline.cc:393] => Image sees 9418 / 11191 points
# I20250617 18:23:52.597138 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:23:56.807311 131932658775872 incremental_pipeline.cc:282] Finding good initial image pair
# I20250617 18:23:57.343061 131932658775872 incremental_pipeline.cc:306] Initializing with image pair #2 and #9
# I20250617 18:23:57.347530 131932658775872 incremental_pipeline.cc:311] Global bundle adjustment
# I20250617 18:23:57.873385 131932658775872 incremental_pipeline.cc:390] Registering image #7 (3)
# I20250617 18:23:57.873432 131932658775872 incremental_pipeline.cc:393] => Image sees 827 / 11783 points
# I20250617 18:23:58.565194 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:23:58.781385 131932658775872 incremental_pipeline.cc:390] Registering image #8 (4)
# I20250617 18:23:58.781429 131932658775872 incremental_pipeline.cc:393] => Image sees 3362 / 9917 points
# I20250617 18:24:00.529440 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:24:01.058768 131932658775872 incremental_pipeline.cc:390] Registering image #6 (5)
# I20250617 18:24:01.058812 131932658775872 incremental_pipeline.cc:393] => Image sees 4690 / 12478 points
# I20250617 18:24:02.771453 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:24:03.376498 131932658775872 incremental_pipeline.cc:390] Registering image #5 (6)
# I20250617 18:24:03.376541 131932658775872 incremental_pipeline.cc:393] => Image sees 5062 / 11865 points
# I20250617 18:24:06.772889 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:24:07.544475 131932658775872 incremental_pipeline.cc:390] Registering image #4 (7)
# I20250617 18:24:07.544525 131932658775872 incremental_pipeline.cc:393] => Image sees 5027 / 9187 points
# I20250617 18:24:11.375663 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:24:12.806593 131932658775872 incremental_pipeline.cc:390] Registering image #3 (8)
# I20250617 18:24:12.806638 131932658775872 incremental_pipeline.cc:393] => Image sees 5501 / 7863 points
# I20250617 18:24:16.100196 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:24:19.293382 131932658775872 incremental_pipeline.cc:390] Registering image #1 (9)
# I20250617 18:24:19.293428 131932658775872 incremental_pipeline.cc:393] => Image sees 10368 / 12259 points
# I20250617 18:24:22.848651 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:24:24.931312 131932658775872 incremental_pipeline.cc:390] Registering image #10 (10)
# I20250617 18:24:24.931361 131932658775872 incremental_pipeline.cc:393] => Image sees 4672 / 5715 points
# I20250617 18:24:27.732215 131932658775872 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250617 18:24:31.186649 131932658775872 timer.cc:91] Elapsed time: 1.164 [minutes]
#
# {0: Reconstruction(num_cameras=9, num_images=9, num_reg_images=9, num_points3D=18337), 1: Reconstruction(num_cameras=10, num_images=10, num_reg_images=10, num_points3D=15279)}
# Dataset "ETs" -> Registered 19 / 22 images with 2 clusters
#
# --------------------------------------------------------------------------------

# %%
# %cd /kaggle/working/
# !rm -r /kaggle/working/mast3r/
# !rm -r /kaggle/working/miniconda/
# !rm -r /kaggle/working/result/
# Out:
# /kaggle/working
