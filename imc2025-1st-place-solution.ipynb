# %%
# !pip config set global.disable-pip-version-check true
# Out:
# Writing to /root/.config/pip/pip.conf

# %%
# !cp /kaggle/input/glomap/glomap_build/glomap /usr/local/bin/
# !chmod 755 /usr/local/bin/glomap

# !cp -r /kaggle/input/glomap/glomap_build glomap_lib
# !rm glomap_lib/librt.so.1  # conflict
# !rm glomap_lib/libdl.so.2
# !rm glomap_lib/libnvJitLink.so.12*

# %%
# !cp -r /kaggle/input/ns64-imc2025lib/lib_py311_t4/custom_ops ./
# !cp /kaggle/input/ns64-imc2025lib/lib_py311_t4/score_computation_cuda.cpython-311-x86_64-linux-gnu.so ./
# !cp /kaggle/input/ns64-imc2025lib/lib_py311_t4/value_aggregation_cuda.cpython-311-x86_64-linux-gnu.so ./

# %%
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/ns64_imc2025lib-0.1.50-py3-none-any.whl
# Out:
# Processing /kaggle/input/ns64-imc2025lib/ns64_imc2025lib-0.1.50-py3-none-any.whl
# Installing collected packages: ns64-imc2025lib
# Successfully installed ns64-imc2025lib-0.1.50

# %%
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/addict-2.4.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/asmk-0.1-cp311-cp311-linux_x86_64.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/attrs-25.3.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/cholespy-2.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/croco-0.1.2-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/curope-0.0.0-cp311-cp311-linux_x86_64.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/dad-0.2.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/dedode-0.0.1-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/dotmap-1.3.30-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/dsine-0.0.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/dust3r-0.1.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/e2cnn-0.2.3-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/einops-0.8.1-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/flask-3.1.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/glcontext-3.0.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/hloc-1.5-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/HTML4Vision-0.5.0-py2.py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/huggingface_hub-0.30.2-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/hydra_core-1.3.2-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/iglovikov_helper_functions-0.0.53-py2.py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/kornia_moons-0.2.9-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/lightglue-0.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/lightning-2.5.1-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/loguru-0.7.3-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/mast3r-0.1.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/mmengine-0.10.7-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/moderngl-5.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/moge-1.0.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/mono-0.0.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/mpsfm-0.1.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/plyfile-1.1-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/pyceres-2.4-cp311-cp311-manylinux_2_28_x86_64.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/pycolmap-3.11.1-cp311-cp311-manylinux_2_28_x86_64.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/superglue_pretrained_network-0.0.0-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/utils3d-0.0.2-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/vggt-0.0.1-py3-none-any.whl
# !pip install --no-deps /kaggle/input/ns64-imc2025lib/yacs-0.1.8-py3-none-any.whl
# Out:
# Processing /kaggle/input/ns64-imc2025lib/addict-2.4.0-py3-none-any.whl
# Installing collected packages: addict
# Successfully installed addict-2.4.0
# Processing /kaggle/input/ns64-imc2025lib/asmk-0.1-cp311-cp311-linux_x86_64.whl
# Installing collected packages: asmk
# Successfully installed asmk-0.1
# Processing /kaggle/input/ns64-imc2025lib/attrs-25.3.0-py3-none-any.whl
# attrs is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing /kaggle/input/ns64-imc2025lib/cholespy-2.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing collected packages: cholespy
# Successfully installed cholespy-2.1.0
# Processing /kaggle/input/ns64-imc2025lib/croco-0.1.2-py3-none-any.whl
# Installing collected packages: croco
# Successfully installed croco-0.1.2
# Processing /kaggle/input/ns64-imc2025lib/curope-0.0.0-cp311-cp311-linux_x86_64.whl
# Installing collected packages: curope
# Successfully installed curope-0.0.0
# Processing /kaggle/input/ns64-imc2025lib/dad-0.2.0-py3-none-any.whl
# Installing collected packages: dad
# Successfully installed dad-0.2.0
# Processing /kaggle/input/ns64-imc2025lib/dedode-0.0.1-py3-none-any.whl
# Installing collected packages: dedode
# Successfully installed dedode-0.0.1
# Processing /kaggle/input/ns64-imc2025lib/dotmap-1.3.30-py3-none-any.whl
# Installing collected packages: dotmap
# Successfully installed dotmap-1.3.30
# Processing /kaggle/input/ns64-imc2025lib/dsine-0.0.0-py3-none-any.whl
# Installing collected packages: dsine
# Successfully installed dsine-0.0.0
# Processing /kaggle/input/ns64-imc2025lib/dust3r-0.1.0-py3-none-any.whl
# Installing collected packages: dust3r
# Successfully installed dust3r-0.1.0
# Processing /kaggle/input/ns64-imc2025lib/e2cnn-0.2.3-py3-none-any.whl
# Installing collected packages: e2cnn
# Successfully installed e2cnn-0.2.3
# Processing /kaggle/input/ns64-imc2025lib/einops-0.8.1-py3-none-any.whl
# einops is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing /kaggle/input/ns64-imc2025lib/faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0
# Processing /kaggle/input/ns64-imc2025lib/flask-3.1.0-py3-none-any.whl
# flask is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing /kaggle/input/ns64-imc2025lib/glcontext-3.0.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing collected packages: glcontext
# Successfully installed glcontext-3.0.0
# Processing /kaggle/input/ns64-imc2025lib/hloc-1.5-py3-none-any.whl
# Installing collected packages: hloc
# Successfully installed hloc-1.5
# Processing /kaggle/input/ns64-imc2025lib/HTML4Vision-0.5.0-py2.py3-none-any.whl
# Installing collected packages: HTML4Vision
# Successfully installed HTML4Vision-0.5.0
# Processing /kaggle/input/ns64-imc2025lib/huggingface_hub-0.30.2-py3-none-any.whl
# huggingface-hub is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing /kaggle/input/ns64-imc2025lib/hydra_core-1.3.2-py3-none-any.whl
# Installing collected packages: hydra-core
# Successfully installed hydra-core-1.3.2
# Processing /kaggle/input/ns64-imc2025lib/iglovikov_helper_functions-0.0.53-py2.py3-none-any.whl
# Installing collected packages: iglovikov-helper-functions
# Successfully installed iglovikov-helper-functions-0.0.53
# Processing /kaggle/input/ns64-imc2025lib/kornia_moons-0.2.9-py3-none-any.whl
# Installing collected packages: kornia-moons
# Successfully installed kornia-moons-0.2.9
# Processing /kaggle/input/ns64-imc2025lib/lightglue-0.0-py3-none-any.whl
# Installing collected packages: lightglue
# Successfully installed lightglue-0.0
# Processing /kaggle/input/ns64-imc2025lib/lightning-2.5.1-py3-none-any.whl
# Installing collected packages: lightning
# Successfully installed lightning-2.5.1
# Processing /kaggle/input/ns64-imc2025lib/loguru-0.7.3-py3-none-any.whl
# Installing collected packages: loguru
# Successfully installed loguru-0.7.3
# Processing /kaggle/input/ns64-imc2025lib/mast3r-0.1.0-py3-none-any.whl
# Installing collected packages: mast3r
# Successfully installed mast3r-0.1.0
# Processing /kaggle/input/ns64-imc2025lib/mmengine-0.10.7-py3-none-any.whl
# Installing collected packages: mmengine
# Successfully installed mmengine-0.10.7
# Processing /kaggle/input/ns64-imc2025lib/moderngl-5.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing collected packages: moderngl
# Successfully installed moderngl-5.12.0
# Processing /kaggle/input/ns64-imc2025lib/moge-1.0.0-py3-none-any.whl
# Installing collected packages: moge
# Successfully installed moge-1.0.0
# Processing /kaggle/input/ns64-imc2025lib/mono-0.0.0-py3-none-any.whl
# Installing collected packages: mono
# Successfully installed mono-0.0.0
# Processing /kaggle/input/ns64-imc2025lib/mpsfm-0.1.0-py3-none-any.whl
# Installing collected packages: mpsfm
# Successfully installed mpsfm-0.1.0
# Processing /kaggle/input/ns64-imc2025lib/plyfile-1.1-py3-none-any.whl
# Installing collected packages: plyfile
# Successfully installed plyfile-1.1
# Processing /kaggle/input/ns64-imc2025lib/pyceres-2.4-cp311-cp311-manylinux_2_28_x86_64.whl
# Installing collected packages: pyceres
# Successfully installed pyceres-2.4
# Processing /kaggle/input/ns64-imc2025lib/pycolmap-3.11.1-cp311-cp311-manylinux_2_28_x86_64.whl
# Installing collected packages: pycolmap
# Successfully installed pycolmap-3.11.1
# Processing /kaggle/input/ns64-imc2025lib/superglue_pretrained_network-0.0.0-py3-none-any.whl
# Installing collected packages: superglue-pretrained-network
# Successfully installed superglue-pretrained-network-0.0.0
# Processing /kaggle/input/ns64-imc2025lib/utils3d-0.0.2-py3-none-any.whl
# Installing collected packages: utils3d
# Successfully installed utils3d-0.0.2
# Processing /kaggle/input/ns64-imc2025lib/vggt-0.0.1-py3-none-any.whl
# Installing collected packages: vggt
# Successfully installed vggt-0.0.1
# Processing /kaggle/input/ns64-imc2025lib/yacs-0.1.8-py3-none-any.whl
# Installing collected packages: yacs
# Successfully installed yacs-0.1.8

# %%
# !mkdir -p hf_grounding_dino_base
# !mkdir -p hf_sam_vit_base
# !mkdir -p hf_vggt_1b
# !mkdir -p siglip2_so400m_patch14_384

# !ln -s /kaggle/input/imc2023models/grounded_sam/models--IDEA-Research--grounding-dino-base/blobs/5548f844c928c4b6f411fa8cbcc2bfa8dbbba437cb1d513975519f93c2a9ed21 ./hf_grounding_dino_base/model.safetensors
# !ln -s /kaggle/input/imc2023models/grounded_sam/models--IDEA-Research--grounding-dino-base/blobs/5a7f6206a1e488c54316e1f594311dd47a03a41b ./hf_grounding_dino_base/config.json
# !ln -s /kaggle/input/imc2023models/grounded_sam/models--IDEA-Research--grounding-dino-base/blobs/5cb45d963917ed130ce46a93204b349cbec21131 ./hf_grounding_dino_base/preprocessor_config.json
# !ln -s /kaggle/input/imc2023models/grounded_sam/models--IDEA-Research--grounding-dino-base/blobs/688882a79f44442ddc1f60d70334a7ff5df0fb47 ./hf_grounding_dino_base/tokenizer.json
# !ln -s /kaggle/input/imc2023models/grounded_sam/models--IDEA-Research--grounding-dino-base/blobs/a8b3208c2884c4efb86e49300fdd3dc877220cdf ./hf_grounding_dino_base/special_tokens_map.json
# !ln -s /kaggle/input/imc2023models/grounded_sam/models--IDEA-Research--grounding-dino-base/blobs/ed97a84add5f9b2091e756765ad3ba087a345e17 ./hf_grounding_dino_base/tokenizer_config.json
# !ln -s /kaggle/input/imc2023models/grounded_sam/models--IDEA-Research--grounding-dino-base/blobs/fb140275c155a9c7c5a3b3e0e77a9e839594a938 ./hf_grounding_dino_base/vocab.txt

# !ln -s /kaggle/input/imc2023models/grounded_sam/models--facebook--sam-vit-base/blobs/5880e4f874dbeb2a1921c9cf3bb44da529e46bf4 ./hf_sam_vit_base/config.json
# !ln -s /kaggle/input/imc2023models/grounded_sam/models--facebook--sam-vit-base/blobs/732fbaf0c512b97d8d9161f51bc157bfb2873d12 ./hf_sam_vit_base/preprocessor_config.json
# !ln -s /kaggle/input/imc2023models/grounded_sam/models--facebook--sam-vit-base/blobs/892c410e496344e527255ccdcb2cb7244a609acb5389c7c4fdba1288f861c579 ./hf_sam_vit_base/model.safetensors

# !ln -s /kaggle/input/imc2025models/models--facebook--VGGT-1B/blobs/303bf21400e2723e8ff9c0c7ceb6d86859b1ddeb ./hf_vggt_1b/config.json
# !ln -s /kaggle/input/imc2025models/models--facebook--VGGT-1B/blobs/f164acf60724910d8fe1578bb499d800850c7bb0948db7555c413f9fbe60467e ./hf_vggt_1b/model.safetensors

# !ln -s /kaggle/input/imc2025models/models--google--siglip2-so400m-patch14-384/blobs/7c1e0ed1759922fc4eb362d3b405958e829f364d ./siglip2_so400m_patch14_384/config.json
# !ln -s /kaggle/input/imc2025models/models--google--siglip2-so400m-patch14-384/blobs/e9e084ab5a0d74573432f1dcf11c1bdd8d9b3655 ./siglip2_so400m_patch14_384/preprocessor_config.json
# !ln -s /kaggle/input/imc2025models/models--google--siglip2-so400m-patch14-384/blobs/9f4f4a49f908ef0c979bce8ff5a5c0e88882dc6c5dc4304387cbbd152558e2c2 ./siglip2_so400m_patch14_384/model.safetensors

# %%
import numpy as np
import yaml
import os
import sys
sys.path.insert(0, '/usr/local/lib/python3.11/dist-packages/ns64_imc2025lib')
os.environ["OPEN3D_DISABLE_WEB_VISUALIZER"] = "true"
os.environ['DEFAULT_DATASET_DIR'] = '/kaggle/input/image-matching-challenge-2025'
os.environ['DEFAULT_TMP_DIR'] = '/kaggle/tmp'
os.environ['DEFAULT_MODEL_LIST_PATH'] = '/kaggle/input/ns64-imc2025lib/models.yaml'
os.environ["TRANSFORMERS_OFFLINE"] = "1"
os.environ["HF_HUB_OFFLINE"] = "1"
#os.environ['DEFAULT_MODEL_LIST_PATH'] = '/kaggle/input/imc2023models/models.yaml'
#os.environ['SCENE_SPACE_DIR_PERSISTENT'] = 'yes'

# %%
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'
import torch
torch.use_deterministic_algorithms(True)

# %%
from ns64_imc2025lib.config import SubmissionConfig
from ns64_imc2025lib.kernel import run_and_save_submission
from ns64_imc2025lib.data import on_kaggle_kernel_rerun
# Out:
# 2025-06-20 18:55:10.137511: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445710.329184      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445710.379384      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Notfound: onnxruntime

# %%
conf = SubmissionConfig.load_config_from_pipeline_config_string("""
# conf/pipeline/imc2025/mast3rhybrid/mast3rhybrid-022-b.yaml
# ------------------------------------
# ------------------------------------
type: imc2025

imc2025_pipeline:
  point_tracking_matchers:
    - type: mast3r_hybrid
      impl_version: v2
      local_features:
        - type: lightglue_aliked
          lightglue_aliked:
            weight_path: ALIKED_LIGHTGLUE_N16
            max_num_keypoints: 4096
          resize:
            func: lightglue
            lg_resize: 1280
        - type: magicleap_superpoint
          magicleap_superpoint:
            weight_path: MAGICLEAP_SUPERPOINT
            nms_radius: 4
            keypoint_threshold: 0.0005
            max_keypoints: 4096
            remove_borders: 4
            fix_sampling: true
          resize:
            func: magicleap
            ml_resize: 1600
      mast3r_hybrid:
        size: 512
        dense_min_matches: 30
        dense_subsample: 6
        dense_pixel_tol: 3
        dense_match_threshold: 1.001
        dense_match_topk: null  # Use all
        sparse_min_matches: 30
        sparse_match_threshold: 1.001
        sparse_match_topk: null  
        model:
          use_amp: true
          weight_path: MAST3R

  shortlist_generator: 
    type: ensemble
    ensemble:
      all_pairs_fallback_threshold: 0
      shortlist_generators:
        - type: mast3r_retrieval_asmk
          mast3r_retrieval_asmk_fallback_threshold: 0
          mast3r_retrieval_asmk_remove_swapped_pairs: true
          mast3r_retrieval_asmk_make_pairs_fps_n: 10
          mast3r_retrieval_asmk_make_pairs_fps_k: 25
          mast3r_retrieval_asmk_make_pairs_fps_dist_threshold: null
          mast3r_retrieval_asmk:
            mast3r:
              weight_path: MAST3R
              retrieval_weight_path: MAST3R_RETRIEVAL
              retrieval_codebook_path: MAST3R_RETRIEVAL_CODEBOOK
        - type: global_desc
          global_desc_model: mast3r_retrieval_spoc
          global_desc_batch_size: 1
          global_desc_num_workers: 1
          global_desc_similar_distance_threshold: 9999
          global_desc_topk: 10
          global_desc_fallback_threshold: 0
          global_desc_remove_swapped_pairs: true
          global_desc_num_refills_when_no_matches: 10
          mast3r_retrieval_spoc:
            mast3r:
              weight_path: MAST3R
              retrieval_weight_path: MAST3R_RETRIEVAL
              retrieval_codebook_path: MAST3R_RETRIEVAL_CODEBOOK
            global_desc_type: retrieval_spoc
        - type: global_desc
          global_desc_model: dinov2
          global_desc_batch_size: 1
          global_desc_num_workers: 1
          global_desc_similar_distance_threshold: 9999
          global_desc_topk: 10
          global_desc_fallback_threshold: 0
          global_desc_remove_swapped_pairs: true
          global_desc_num_refills_when_no_matches: 10
          dinov2:
            pretrained_model: DINOV2_BASE
        - type: global_desc
          global_desc_model: isc
          global_desc_batch_size: 1
          global_desc_num_workers: 1
          global_desc_similar_distance_threshold: 9999
          global_desc_topk: 10
          global_desc_fallback_threshold: 0
          global_desc_remove_swapped_pairs: true
          global_desc_num_refills_when_no_matches: 10
          isc:
            weight_path: ISC
  
  reconstruction:
    fill_zero_Rt: false
    fill_nan_Rt: false
    fill_nearest_position: false
    mapper_min_model_size: 3
    mapper_max_num_models: 25
  
  clustering: null
""")
print(conf.model_dump_json(indent=4))

with open("config.yaml", "w") as fp:
    yaml.safe_dump(conf.model_dump(), fp)
# Out:
# {
#     "pipeline": {
#         "type": "imc2025",
#         "detector_based_pipeline": null,
#         "detector_free_pipeline": null,
#         "pre_matching_ensemble_pipeline": null,
#         "simple_ensemble_pipeline": null,
#         "imc2024_pipeline": null,
#         "dust3r_pipeline": null,
#         "localizer_pipeline": null,
#         "imc2025_pipeline": {
#             "shortlist_generator": {
#                 "type": "ensemble",
#                 "global_desc_model": null,
#                 "global_desc_batch_size": 16,
#                 "global_desc_num_workers": 2,
#                 "global_desc_similar_distance_threshold": 0.6,
#                 "global_desc_topk": 20,
#                 "global_desc_fallback_threshold": 20,
#                 "global_desc_remove_swapped_pairs": false,
#                 "global_desc_num_refills_when_no_matches": 0,
#                 "global_desc_compute_feats_if_fallback": false,
#                 "global_desc_fps_n": null,
#                 "global_desc_fps_k": null,
#                 "global_desc_fps_dist_threshold": null,
#                 "cvnet_rerank_alpha": 0.5,
#                 "cvnet_rerank_threshold": 1.0,
#                 "cvnet_rerank_batch_size": 16,
#                 "cvnet_rerank_num_workers": 2,
#                 "cvnet_rerank_image_size_height": null,
#                 "cvnet_rerank_image_size_width": null,
#                 "gdcc_degree_threshold": null,
#                 "random_walk_matching_threshold": null,
#                 "random_walk_num_trials_per_sample": null,
#                 "random_walk_num_references_per_sample": null,
#                 "random_walk_ransac": null,
#                 "mast3r_retrieval_asmk_fallback_threshold": null,
#                 "mast3r_retrieval_asmk_remove_swapped_pairs": false,
#                 "mast3r_retrieval_asmk_make_pairs_fps_n": 0,
#                 "mast3r_retrieval_asmk_make_pairs_fps_k": 1,
#                 "mast3r_retrieval_asmk_make_pairs_fps_dist_threshold": null,
#                 "apgem": null,
#                 "cvnet": null,
#                 "dinov2": null,
#                 "dinov2_salad": null,
#                 "patchnetvlad": null,
#                 "mast3r_spoc": null,
#                 "mast3r_retrieval_spoc": null,
#                 "mast3r_retrieval_asmk": null,
#                 "moge": null,
#                 "moge_depth_hog": null,
#                 "moge_dinov2": null,
#                 "doppelgangers": null,
#                 "siglip2": null,
#                 "isc": null,
#                 "ensemble": {
#                     "shortlist_generators": [
#                         {
#                             "type": "mast3r_retrieval_asmk",
#                             "global_desc_model": null,
#                             "global_desc_batch_size": 16,
#                             "global_desc_num_workers": 2,
#                             "global_desc_similar_distance_threshold": 0.6,
#                             "global_desc_topk": 20,
#                             "global_desc_fallback_threshold": 20,
#                             "global_desc_remove_swapped_pairs": false,
#                             "global_desc_num_refills_when_no_matches": 0,
#                             "global_desc_compute_feats_if_fallback": false,
#                             "global_desc_fps_n": null,
#                             "global_desc_fps_k": null,
#                             "global_desc_fps_dist_threshold": null,
#                             "cvnet_rerank_alpha": 0.5,
#                             "cvnet_rerank_threshold": 1.0,
#                             "cvnet_rerank_batch_size": 16,
#                             "cvnet_rerank_num_workers": 2,
#                             "cvnet_rerank_image_size_height": null,
#                             "cvnet_rerank_image_size_width": null,
#                             "gdcc_degree_threshold": null,
#                             "random_walk_matching_threshold": null,
#                             "random_walk_num_trials_per_sample": null,
#                             "random_walk_num_references_per_sample": null,
#                             "random_walk_ransac": null,
#                             "mast3r_retrieval_asmk_fallback_threshold": 0,
#                             "mast3r_retrieval_asmk_remove_swapped_pairs": true,
#                             "mast3r_retrieval_asmk_make_pairs_fps_n": 10,
#                             "mast3r_retrieval_asmk_make_pairs_fps_k": 25,
#                             "mast3r_retrieval_asmk_make_pairs_fps_dist_threshold": null,
#                             "apgem": null,
#                             "cvnet": null,
#                             "dinov2": null,
#                             "dinov2_salad": null,
#                             "patchnetvlad": null,
#                             "mast3r_spoc": null,
#                             "mast3r_retrieval_spoc": null,
#                             "mast3r_retrieval_asmk": {
#                                 "mast3r": {
#                                     "weight_path": "MAST3R",
#                                     "use_amp": false,
#                                     "retrieval_weight_path": "MAST3R_RETRIEVAL",
#                                     "retrieval_codebook_path": "MAST3R_RETRIEVAL_CODEBOOK"
#                                 }
#                             },
#                             "moge": null,
#                             "moge_depth_hog": null,
#                             "moge_dinov2": null,
#                             "doppelgangers": null,
#                             "siglip2": null,
#                             "isc": null,
#                             "ensemble": null,
#                             "compat_version": "v1"
#                         },
#                         {
#                             "type": "global_desc",
#                             "global_desc_model": "mast3r_retrieval_spoc",
#                             "global_desc_batch_size": 1,
#                             "global_desc_num_workers": 1,
#                             "global_desc_similar_distance_threshold": 9999.0,
#                             "global_desc_topk": 10,
#                             "global_desc_fallback_threshold": 0,
#                             "global_desc_remove_swapped_pairs": true,
#                             "global_desc_num_refills_when_no_matches": 10,
#                             "global_desc_compute_feats_if_fallback": false,
#                             "global_desc_fps_n": null,
#                             "global_desc_fps_k": null,
#                             "global_desc_fps_dist_threshold": null,
#                             "cvnet_rerank_alpha": 0.5,
#                             "cvnet_rerank_threshold": 1.0,
#                             "cvnet_rerank_batch_size": 16,
#                             "cvnet_rerank_num_workers": 2,
#                             "cvnet_rerank_image_size_height": null,
#                             "cvnet_rerank_image_size_width": null,
#                             "gdcc_degree_threshold": null,
#                             "random_walk_matching_threshold": null,
#                             "random_walk_num_trials_per_sample": null,
#                             "random_walk_num_references_per_sample": null,
#                             "random_walk_ransac": null,
#                             "mast3r_retrieval_asmk_fallback_threshold": null,
#                             "mast3r_retrieval_asmk_remove_swapped_pairs": false,
#                             "mast3r_retrieval_asmk_make_pairs_fps_n": 0,
#                             "mast3r_retrieval_asmk_make_pairs_fps_k": 1,
#                             "mast3r_retrieval_asmk_make_pairs_fps_dist_threshold": null,
#                             "apgem": null,
#                             "cvnet": null,
#                             "dinov2": null,
#                             "dinov2_salad": null,
#                             "patchnetvlad": null,
#                             "mast3r_spoc": null,
#                             "mast3r_retrieval_spoc": {
#                                 "mast3r": {
#                                     "weight_path": "MAST3R",
#                                     "use_amp": false,
#                                     "retrieval_weight_path": "MAST3R_RETRIEVAL",
#                                     "retrieval_codebook_path": "MAST3R_RETRIEVAL_CODEBOOK"
#                                 },
#                                 "global_desc_type": "retrieval_spoc"
#                             },
#                             "mast3r_retrieval_asmk": null,
#                             "moge": null,
#                             "moge_depth_hog": null,
#                             "moge_dinov2": null,
#                             "doppelgangers": null,
#                             "siglip2": null,
#                             "isc": null,
#                             "ensemble": null,
#                             "compat_version": "v1"
#                         },
#                         {
#                             "type": "global_desc",
#                             "global_desc_model": "dinov2",
#                             "global_desc_batch_size": 1,
#                             "global_desc_num_workers": 1,
#                             "global_desc_similar_distance_threshold": 9999.0,
#                             "global_desc_topk": 10,
#                             "global_desc_fallback_threshold": 0,
#                             "global_desc_remove_swapped_pairs": true,
#                             "global_desc_num_refills_when_no_matches": 10,
#                             "global_desc_compute_feats_if_fallback": false,
#                             "global_desc_fps_n": null,
#                             "global_desc_fps_k": null,
#                             "global_desc_fps_dist_threshold": null,
#                             "cvnet_rerank_alpha": 0.5,
#                             "cvnet_rerank_threshold": 1.0,
#                             "cvnet_rerank_batch_size": 16,
#                             "cvnet_rerank_num_workers": 2,
#                             "cvnet_rerank_image_size_height": null,
#                             "cvnet_rerank_image_size_width": null,
#                             "gdcc_degree_threshold": null,
#                             "random_walk_matching_threshold": null,
#                             "random_walk_num_trials_per_sample": null,
#                             "random_walk_num_references_per_sample": null,
#                             "random_walk_ransac": null,
#                             "mast3r_retrieval_asmk_fallback_threshold": null,
#                             "mast3r_retrieval_asmk_remove_swapped_pairs": false,
#                             "mast3r_retrieval_asmk_make_pairs_fps_n": 0,
#                             "mast3r_retrieval_asmk_make_pairs_fps_k": 1,
#                             "mast3r_retrieval_asmk_make_pairs_fps_dist_threshold": null,
#                             "apgem": null,
#                             "cvnet": null,
#                             "dinov2": {
#                                 "pretrained_model": "DINOV2_BASE",
#                                 "options": null
#                             },
#                             "dinov2_salad": null,
#                             "patchnetvlad": null,
#                             "mast3r_spoc": null,
#                             "mast3r_retrieval_spoc": null,
#                             "mast3r_retrieval_asmk": null,
#                             "moge": null,
#                             "moge_depth_hog": null,
#                             "moge_dinov2": null,
#                             "doppelgangers": null,
#                             "siglip2": null,
#                             "isc": null,
#                             "ensemble": null,
#                             "compat_version": "v1"
#                         },
#                         {
#                             "type": "global_desc",
#                             "global_desc_model": "isc",
#                             "global_desc_batch_size": 1,
#                             "global_desc_num_workers": 1,
#                             "global_desc_similar_distance_threshold": 9999.0,
#                             "global_desc_topk": 10,
#                             "global_desc_fallback_threshold": 0,
#                             "global_desc_remove_swapped_pairs": true,
#                             "global_desc_num_refills_when_no_matches": 10,
#                             "global_desc_compute_feats_if_fallback": false,
#                             "global_desc_fps_n": null,
#                             "global_desc_fps_k": null,
#                             "global_desc_fps_dist_threshold": null,
#                             "cvnet_rerank_alpha": 0.5,
#                             "cvnet_rerank_threshold": 1.0,
#                             "cvnet_rerank_batch_size": 16,
#                             "cvnet_rerank_num_workers": 2,
#                             "cvnet_rerank_image_size_height": null,
#                             "cvnet_rerank_image_size_width": null,
#                             "gdcc_degree_threshold": null,
#                             "random_walk_matching_threshold": null,
#                             "random_walk_num_trials_per_sample": null,
#                             "random_walk_num_references_per_sample": null,
#                             "random_walk_ransac": null,
#                             "mast3r_retrieval_asmk_fallback_threshold": null,
#                             "mast3r_retrieval_asmk_remove_swapped_pairs": false,
#                             "mast3r_retrieval_asmk_make_pairs_fps_n": 0,
#                             "mast3r_retrieval_asmk_make_pairs_fps_k": 1,
#                             "mast3r_retrieval_asmk_make_pairs_fps_dist_threshold": null,
#                             "apgem": null,
#                             "cvnet": null,
#                             "dinov2": null,
#                             "dinov2_salad": null,
#                             "patchnetvlad": null,
#                             "mast3r_spoc": null,
#                             "mast3r_retrieval_spoc": null,
#                             "mast3r_retrieval_asmk": null,
#                             "moge": null,
#                             "moge_depth_hog": null,
#                             "moge_dinov2": null,
#                             "doppelgangers": null,
#                             "siglip2": null,
#                             "isc": {
#                                 "weight_path": "ISC"
#                             },
#                             "ensemble": null,
#                             "compat_version": "v1"
#                         }
#                     ],
#                     "all_pairs_fallback_threshold": 0
#                 },
#                 "compat_version": "v1"
#             },
#             "deblurring": null,
#             "orientation_normalization": null,
#             "segmentation": null,
#             "depth_estimation": null,
#             "pre_matching": null,
#             "overlap_region_estimation": null,
#             "masking": null,
#             "shortlist_updater": null,
#             "local_features": [],
#             "local_feature_matchers": [],
#             "detector_free_matchers": [],
#             "point_tracking_matchers": [
#                 {
#                     "type": "mast3r_hybrid",
#                     "local_features": [
#                         {
#                             "type": "lightglue_aliked",
#                             "resize": {
#                                 "func": "lightglue",
#                                 "size": null,
#                                 "small_edge_length": null,
#                                 "long_edge_length": null,
#                                 "antialias": false,
#                                 "divisible_factor": null,
#                                 "pad_bottom_right": false,
#                                 "cv2_interpolation": null,
#                                 "target_size_height": null,
#                                 "target_size_width": null,
#                                 "ml_resize": null,
#                                 "lg_resize": 1280,
#                                 "gim_resize": null
#                             },
#                             "rotation": null,
#                             "ignore_cropper": false,
#                             "extract_from_pre_sampled_keypoints": false,
#                             "pre_sampled_keypoints_interpolation_num": null,
#                             "alike": null,
#                             "aliked": null,
#                             "dad": null,
#                             "darkfeat": null,
#                             "lightglue_aliked": {
#                                 "weight_path": "ALIKED_LIGHTGLUE_N16",
#                                 "model_name": "aliked-n16",
#                                 "max_num_keypoints": 4096,
#                                 "detection_threshold": 0.01,
#                                 "resize": 1024,
#                                 "implement_version": "v1"
#                             },
#                             "lightglue_aliked_dedode_v2": null,
#                             "lightglue_aliked_tile": null,
#                             "dedode": null,
#                             "delf_pytorch": null,
#                             "disk": null,
#                             "edgepoint2": null,
#                             "featurebooster": null,
#                             "featureset": null,
#                             "gim_superpoint": null,
#                             "hardnet": null,
#                             "hardnet8": null,
#                             "lanet": null,
#                             "lightglue_disk": null,
#                             "lightglue_doghardnet": null,
#                             "lightglue_sift": null,
#                             "mtldesc": null,
#                             "multiscale": null,
#                             "posfeat": null,
#                             "relf": null,
#                             "sfd2": null,
#                             "superpoint": null,
#                             "xfeat": null,
#                             "magicleap_superpoint": null,
#                             "lightglue_superpoint": null,
#                             "silk": null
#                         },
#                         {
#                             "type": "magicleap_superpoint",
#                             "resize": {
#                                 "func": "magicleap",
#                                 "size": null,
#                                 "small_edge_length": null,
#                                 "long_edge_length": null,
#                                 "antialias": false,
#                                 "divisible_factor": null,
#                                 "pad_bottom_right": false,
#                                 "cv2_interpolation": null,
#                                 "target_size_height": null,
#                                 "target_size_width": null,
#                                 "ml_resize": 1600,
#                                 "lg_resize": null,
#                                 "gim_resize": null
#                             },
#                             "rotation": null,
#                             "ignore_cropper": false,
#                             "extract_from_pre_sampled_keypoints": false,
#                             "pre_sampled_keypoints_interpolation_num": null,
#                             "alike": null,
#                             "aliked": null,
#                             "dad": null,
#                             "darkfeat": null,
#                             "lightglue_aliked": null,
#                             "lightglue_aliked_dedode_v2": null,
#                             "lightglue_aliked_tile": null,
#                             "dedode": null,
#                             "delf_pytorch": null,
#                             "disk": null,
#                             "edgepoint2": null,
#                             "featurebooster": null,
#                             "featureset": null,
#                             "gim_superpoint": null,
#                             "hardnet": null,
#                             "hardnet8": null,
#                             "lanet": null,
#                             "lightglue_disk": null,
#                             "lightglue_doghardnet": null,
#                             "lightglue_sift": null,
#                             "mtldesc": null,
#                             "multiscale": null,
#                             "posfeat": null,
#                             "relf": null,
#                             "sfd2": null,
#                             "superpoint": null,
#                             "xfeat": null,
#                             "magicleap_superpoint": {
#                                 "weight_path": "MAGICLEAP_SUPERPOINT",
#                                 "nms_radius": 4,
#                                 "keypoint_threshold": 0.0005,
#                                 "max_keypoints": 4096,
#                                 "remove_borders": 4,
#                                 "fix_sampling": true
#                             },
#                             "lightglue_superpoint": null,
#                             "silk": null
#                         }
#                     ],
#                     "impl_version": "v2",
#                     "apply_round": true,
#                     "matching_filter": null,
#                     "vggt": null,
#                     "mast3r_mpsfm_sparse": null,
#                     "mast3r_sparse": null,
#                     "mast3r_hybrid": {
#                         "model": {
#                             "weight_path": "MAST3R",
#                             "use_amp": true,
#                             "retrieval_weight_path": null,
#                             "retrieval_codebook_path": null
#                         },
#                         "size": 512,
#                         "prefer_sparse_matches": false,
#                         "prefer_sparse_kernel_size": 5,
#                         "dense_min_matches": 30,
#                         "dense_subsample": 6,
#                         "dense_pixel_tol": 3,
#                         "dense_match_threshold": 1.001,
#                         "dense_match_topk": null,
#                         "sparse_min_matches": 30,
#                         "sparse_match_threshold": 1.001,
#                         "sparse_match_topk": null
#                     }
#                 }
#             ],
#             "line2d_features": [],
#             "line2d_matchers": [],
#             "post_localizer": null,
#             "hloc_match_dense": null,
#             "filtering": null,
#             "refinement": null,
#             "verification": {
#                 "type": "colmap",
#                 "ransac": null,
#                 "poselib_ransac": null,
#                 "fsnet": null
#             },
#             "pruning": null,
#             "reconstruction": {
#                 "camera_model": "simple-radial",
#                 "fill_zero_Rt": false,
#                 "fill_nan_Rt": false,
#                 "fill_nearest_position": false,
#                 "use_localize_sfm": false,
#                 "use_localize_pixloc": false,
#                 "mapper_min_model_size": 3,
#                 "mapper_max_num_models": 25,
#                 "mapper_min_num_matches": null,
#                 "mapper_multiple_models": null,
#                 "mapper_filter_max_reproj_error": null,
#                 "set_scene_graph_center_node_to_init_image_id1": false
#             },
#             "clustering": null,
#             "use_glomap": false,
#             "seed": 1234
#         },
#         "imc2025_mast3r_pipeline": null,
#         "pipeline_id": null
#     },
#     "target_data_type": "submission",
#     "datasets_to_ignore": null,
#     "datasets_to_use": null,
#     "scenes_to_ignore": null,
#     "scenes_to_use": null,
#     "dist_output_dir": ".dist_output"
# }

# %%
# !PYTHONPATH=/usr/local/lib/python3.11/dist-packages/ns64_imc2025lib:$PYTHONPATH OMP_NUM_THREADS=1 MKL_NUM_THREADS=1 \
 LD_LIBRARY_PATH=./glomap_lib:$LD_LIBRARY_PATH \
 OPEN3D_DISABLE_WEB_VISUALIZER=true HF_HUB_OFFLINE=1 TRANSFORMERS_OFFLINE=1 DEFAULT_DATASET_DIR=/kaggle/input/image-matching-challenge-2025 \
 CUBLAS_WORKSPACE_CONFIG=':4096:8' \
 DEFAULT_TMP_DIR=/kaggle/tmp DEFAULT_MODEL_LIST_PATH=/kaggle/input/ns64-imc2025lib/models.yaml \
 torchrun --nnodes 1 --nproc_per_node 2 --standalone -m ns64_imc2025lib.kernel -c config.yaml --env-name kernel --dist --kaggle-submit
# Out:
# 2025-06-20 18:55:46.278525: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-20 18:55:46.278564: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445746.301696     282 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445746.301715     281 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445746.308367     282 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1750445746.308410     281 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Distributed: On
# Distributed: On
# device = cuda:0
# DataSchema: IMC2025TestData(data_root_dir=PosixPath('/kaggle/input/image-matching-challenge-2025'), columns=('image_id', 'dataset', 'scene', 'image', 'rotation_matrix', 'translation_vector'))
# [rank=0] Datasets: ['ETs']
# SEED=1234
# ... loading model from ../input/imc2025models/mast3r/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth
# device = cuda:1
# DataSchema: IMC2025TestData(data_root_dir=PosixPath('/kaggle/input/image-matching-challenge-2025'), columns=('image_id', 'dataset', 'scene', 'image', 'rotation_matrix', 'translation_vector'))
# [rank=1] Datasets: []
# SEED=1234
# ... loading model from ../input/imc2025models/mast3r/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth
# instantiating : AsymmetricMASt3R(enc_depth=24, dec_depth=12, enc_embed_dim=1024, dec_embed_dim=768, enc_num_heads=16, dec_num_heads=12, pos_embed='RoPE100',img_size=(512, 512), head_type='catmlp+dpt', output_mode='pts3d+desc24', depth_mode=('exp', -inf, inf), conf_mode=('exp', 1, inf), patch_embed_cls='PatchEmbedDust3R', two_confs=True, desc_conf_mode=('exp', 0, inf), landscape_only=False)instantiating : AsymmetricMASt3R(enc_depth=24, dec_depth=12, enc_embed_dim=1024, dec_embed_dim=768, enc_num_heads=16, dec_num_heads=12, pos_embed='RoPE100',img_size=(512, 512), head_type='catmlp+dpt', output_mode='pts3d+desc24', depth_mode=('exp', -inf, inf), conf_mode=('exp', 1, inf), patch_embed_cls='PatchEmbedDust3R', two_confs=True, desc_conf_mode=('exp', 0, inf), landscape_only=False)
#
# <All keys matched successfully>
# <All keys matched successfully>
# Loading retrieval model from ../input/imc2025models/mast3r_retrieval/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_trainingfree.pth
# Loading retrieval model from ../input/imc2025models/mast3r_retrieval/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_trainingfree.pth
# Return MASt3R model from the cache
# Loading retrieval model from ../input/imc2025models/mast3r_retrieval/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_trainingfree.pth
# Return MASt3R model from the cache
# Loading retrieval model from ../input/imc2025models/mast3r_retrieval/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_trainingfree.pth
# [MASt3RRetrievalSPoCGlobalDescriptorExtractor] weight=../input/imc2025models/mast3r/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth, retrieval_weight=../input/imc2025models/mast3r_retrieval/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_trainingfree.pth, retrieval_codebook=../input/imc2025models/mast3r_retrieval/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_codebook.pkl,
# [MASt3RRetrievalSPoCGlobalDescriptorExtractor] weight=../input/imc2025models/mast3r/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth, retrieval_weight=../input/imc2025models/mast3r_retrieval/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_trainingfree.pth, retrieval_codebook=../input/imc2025models/mast3r_retrieval/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric_retrieval_codebook.pkl,
# DINOv2GlobalDescriptorExtractor: pooling_type=max
# DINOv2GlobalDescriptorExtractor: pooling_type=max
# EnsembleShortlistGenerator | shortlist_generators: ['MASt3RRetrievalASMKShortlistGenerator', 'GlobalDescriptorShortlistGenerator', 'GlobalDescriptorShortlistGenerator', 'GlobalDescriptorShortlistGenerator']
# EnsembleShortlistGenerator | shortlist_generators: ['MASt3RRetrievalASMKShortlistGenerator', 'GlobalDescriptorShortlistGenerator', 'GlobalDescriptorShortlistGenerator', 'GlobalDescriptorShortlistGenerator']
# [ALIKEDLightGlue] weight=/kaggle/input/aliked/pytorch/aliked-n16/1/aliked-n16.pth
# [ALIKEDLightGlue] weight=/kaggle/input/aliked/pytorch/aliked-n16/1/aliked-n16.pth
# MASt3RHybridMatcher | local_features=LightGlueALIKEDHandler
# MagicLeap SuperPoint use sample_descriptors_fix_sampling()
# MASt3RHybridMatcher | local_features=LightGlueALIKEDHandler
# MagicLeap SuperPoint use sample_descriptors_fix_sampling()
# Loaded SuperPoint model
# Loaded SuperPoint model
# Load weights from ../input/imc2023models/research_only/magicleap/superpoint_v1.pth
# Load weights from ../input/imc2023models/research_only/magicleap/superpoint_v1.pth
# MagicLeapSuperPoint has a research-only license !!
# MASt3RHybridMatcher | local_features=MagicLeapSuperPointHandler
# MASt3R: size=512
# MagicLeapSuperPoint has a research-only license !!
# MASt3RHybridMatcher | local_features=MagicLeapSuperPointHandler
# Return MASt3R model from the cacheMASt3R: size=512
#
# Return MASt3R model from the cache
# IMC2025Pipeline starts
# IMC2025Pipeline starts
# The data list has been loaded. # of datasets: 0
# IMC2025Pipeline: 0it [00:00, ?it/s]results_to_submission_df (schema=imc2025)
# -----------------------------------------
# Pre-clustered results
#
# -----------------------------------------
# Final-clustered results
# IMC2025Pipeline: 1it [00:00, 2107.69it/s]
# The data list has been loaded. # of datasets: 1
# IMC2025Pipeline::ETs (1/1):   0%|                         | 0/1 [00:00<?, ?it/s][rank=1] Saved: submission.csv
# [rank=1] Done
# 2025-06-20 18:56:50.474756: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445810.496953     311 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445810.503692     311 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-20 18:56:50.669896: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445810.692285     308 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445810.699038     308 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Cached: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et001.png
# Cached: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et002.png
# Cached: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et003.png
# Cached: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et004.png
# Cached: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et005.png
# [MASt3RRetrievalASMKShortlistGenerator] Creating a sim matrix
#
#   0%|                                                     | 0/5 [00:00<?, ?it/s]2025-06-20 18:57:17.482346: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445837.575170     330 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445837.597743     330 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-20 18:57:17.765425: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445837.843662     336 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445837.866794     336 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-20 18:57:17.985750: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445838.025691     333 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445838.044391     333 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-20 18:57:18.055952: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445838.124051     329 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445838.147029     329 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-20 18:57:18.488854: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-20 18:57:18.518208: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-20 18:57:18.521737: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445838.558301     335 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445838.577828     335 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445838.586273     331 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445838.596814     332 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445838.608954     331 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1750445838.614635     332 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-20 18:57:18.766330: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445838.841471     334 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445838.864816     334 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
#
#  20%|█████████                                    | 1/5 [00:38<02:33, 38.46s/it]
#  40%|██████████████████                           | 2/5 [00:38<00:47, 15.92s/it]
#  60%|███████████████████████████                  | 3/5 [00:38<00:17,  8.71s/it]
#  80%|████████████████████████████████████         | 4/5 [00:38<00:05,  5.32s/it]
# 100%|█████████████████████████████████████████████| 5/5 [00:45<00:00,  9.11s/it]
# Building IVF based on feat(1500)
# Building IVF: Done
# [MASt3RRetrievalASMKShortlistGenerator] Making pairs
# 2025-06-20 18:57:54.163255: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445874.185433     448 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445874.192085     448 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# IMC2025Pipeline::ETs (1/1):   0%| | 0/1 [01:16<?, ?it/s, Global descriptors extr[Scene] Warning! Shortlist already exists
# [Scene] Updated: 11 -> 10
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 2025-06-20 18:58:08.280341: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445888.302316     465 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445888.308969     465 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# IMC2025Pipeline::ETs (1/1):   0%| | 0/1 [01:30<?, ?it/s, Global descriptors extr[Scene] Warning! Shortlist already exists
# [Scene] Updated: 10 -> 10
# [Scene] Warning! Topk table already exists
# 2025-06-20 18:58:22.042272: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750445902.064522     482 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750445902.071751     482 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/ns64_imc2025lib/models/gim/gluefactory/models/matchers/lightglue.py:21: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Notfound: onnxruntime
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# IMC2025Pipeline::ETs (1/1):   0%| | 0/1 [01:44<?, ?it/s, Global descriptors extr[Scene] Warning! Shortlist already exists
# [Scene] Updated: 10 -> 10
# [Scene] Warning! Topk table already exists
# --------------------------
# EnsembleShortlistGenerator
# --------------------------
# MASt3RRetrievalASMKShortlistGenerator
# 11
# 11
# GlobalDescriptorShortlistGenerator
# 10
# 21
# GlobalDescriptorShortlistGenerator
# 10
# 31
# GlobalDescriptorShortlistGenerator
# 10
# 41
# --------------------------
# [Scene] Warning! Shortlist already exists
# [Scene] Updated: 10 -> 11
# [Scene(dataset="ETs", scene="cluster0")] # of pairs: 11
# IMC2025Pipeline::ETs (1/1):   0%| | 0/1 [01:54<?, ?it/s, Point tracking matching
# colmap.add_keypoints: 100%|███████████████████████| 5/5 [00:00<00:00, 62.81it/s]
#
# colmap.add_matches: 11it [00:00, 12251.02it/s]
# I20250620 18:58:38.801855 132401712850496 misc.cc:44]
# ==============================================================================
# Feature matching
# ==============================================================================
# I20250620 18:58:38.802284 132397047739968 sift.cc:1432] Creating SIFT CPU feature matcher
# I20250620 18:58:38.802384 132401712850496 pairing.cc:168] Generating exhaustive image pairs...
# I20250620 18:58:38.802426 132401712850496 pairing.cc:201] Matching block [1/1, 1/1]
# I20250620 18:58:39.938004 132401712850496 feature_matching.cc:46] in 1.136s
# I20250620 18:58:39.940537 132401712850496 timer.cc:91] Elapsed time: 0.019 [minutes]
# Release from cache: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et001.png
# Release from cache: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et002.png
# Release from cache: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et003.png
# Release from cache: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et004.png
# Release from cache: /kaggle/input/image-matching-challenge-2025/test/ETs/another_et_another_et005.png
# I20250620 18:58:40.361311 132408586511552 incremental_pipeline.cc:237] Loading database
# I20250620 18:58:40.362436 132408586511552 database_cache.cc:66] Loading cameras...
# I20250620 18:58:40.362486 132408586511552 database_cache.cc:76]  5 in 0.000s
# I20250620 18:58:40.362511 132408586511552 database_cache.cc:84] Loading matches...
# I20250620 18:58:40.363235 132408586511552 database_cache.cc:89]  10 in 0.001s
# I20250620 18:58:40.363261 132408586511552 database_cache.cc:105] Loading images...
# I20250620 18:58:40.365753 132408586511552 database_cache.cc:153]  5 in 0.002s (connected 5)
# I20250620 18:58:40.365781 132408586511552 database_cache.cc:164] Loading pose priors...
# I20250620 18:58:40.365857 132408586511552 database_cache.cc:175]  0 in 0.000s
# I20250620 18:58:40.365875 132408586511552 database_cache.cc:184] Building correspondence graph...
# I20250620 18:58:40.379050 132408586511552 database_cache.cc:210]  in 0.013s (ignored 0)
# I20250620 18:58:40.379081 132408586511552 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20250620 18:58:40.379945 132408586511552 incremental_pipeline.cc:282] Finding good initial image pair
# I20250620 18:58:41.611435 132408586511552 incremental_pipeline.cc:306] Initializing with image pair #5 and #3
# I20250620 18:58:41.631097 132408586511552 incremental_pipeline.cc:311] Global bundle adjustment
# I20250620 18:58:42.474972 132408586511552 incremental_pipeline.cc:390] Registering image #4 (3)
# I20250620 18:58:42.475007 132408586511552 incremental_pipeline.cc:393] => Image sees 5000 / 18203 points
# I20250620 18:58:45.073597 132408586511552 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250620 18:58:45.971896 132408586511552 incremental_pipeline.cc:390] Registering image #2 (4)
# I20250620 18:58:45.971936 132408586511552 incremental_pipeline.cc:393] => Image sees 10586 / 22218 points
# I20250620 18:58:49.231497 132408586511552 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250620 18:58:50.974800 132408586511552 incremental_pipeline.cc:390] Registering image #1 (5)
# I20250620 18:58:50.974838 132408586511552 incremental_pipeline.cc:393] => Image sees 14083 / 20421 points
# I20250620 18:58:54.707547 132408586511552 incremental_pipeline.cc:42] Retriangulation and Global bundle adjustment
# I20250620 18:58:57.555981 132408586511552 timer.cc:91] Elapsed time: 0.287 [minutes]
# # of reconstruction models = 1
# 0 Reconstruction:
# 	num_cameras = 5
# 	num_images = 5
# 	num_reg_images = 5
# 	num_points3D = 18440
# 	num_observations = 83255
# 	mean_track_length = 4.51491
# 	mean_observations_per_image = 16651
# 	mean_reprojection_error = 0.615325
# IMC2025Pipeline::ETs (1/1): 100%|█| 1/1 [02:14<00:00, 134.22s/it, Point trackingresults_to_submission_df (schema=imc2025)
# -----------------------------------------
# Pre-clustered results
#   * dataset=ETs
#     - scene=cluster0 (#preds=5)
#
#  - another_et_another_et001.png: cluster0 -> cluster0
#  - another_et_another_et002.png: cluster0 -> cluster0
#  - another_et_another_et003.png: cluster0 -> cluster0
#  - another_et_another_et004.png: cluster0 -> cluster0
#  - another_et_another_et005.png: cluster0 -> cluster0
# -----------------------------------------
# Final-clustered results
#   * dataset=ETs
#     - scene=cluster0 (#preds=5)
# IMC2025Pipeline::ETs (1/1): 100%|█| 1/1 [02:14<00:00, 134.22s/it, Point tracking
# [rank=0] Saved: submission.csv
# [rank=0] Waiting all submissions ...
# Found: all submission parts
# [rank=0] Done
# [rank0]:[W620 18:58:59.312538355 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())

# %%
RUN_SINGLE_PROCESS = False
if RUN_SINGLE_PROCESS:
    print("RUN_SINGLE_PROCESS=True")
    if on_kaggle_kernel_rerun():
        run_and_save_submission(conf)
    else:
        conf.target_data_type = 'submission-fast-commit'
        run_and_save_submission(conf)

# %%
# !ls submission.csv
# Out:
# submission.csv
